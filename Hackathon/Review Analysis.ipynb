# %% [markdown]
# # Review Analysis

# %% [markdown]
# ## Import Required Packages

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read Review Data

# %%
review = pd.read_excel('Product Reviews.xlsx')
review
# Out:
#                          Category  \
# 0                      Anti-Aging
# 1                      Anti-Aging
# 2    Sensitive Skin - Calm Series
# 3    Sensitive Skin - Calm Series
# 4                  Very Oily Skin
# 5               Acne Clear Series
# 6                      Anti-Aging
# 7                      Anti-Aging
# 8                      Anti-Aging
# 9                  Very Oily Skin
# 10                 Very Oily Skin
# 11                     Anti-Aging
# 12                     Anti-Aging
# 13                 Very Oily Skin
# 14                     Combi Skin
# 15                     Anti-Aging
# 16                     Anti-Aging
# 17                     Anti-Aging
# 18                 Very Oily Skin
# 19                     Anti-Aging
# 20                     Anti-Aging
# 21                     Anti-Aging
# 22                     Anti-Aging
# 23              Acne Clear Series
# 24                     Anti-Aging
# 25                     Anti-Aging
# 26                     Anti-Aging
# 27   Sensitive Skin - Calm Series
# 28                     Anti-Aging
# 29                 Very Oily Skin
# ..                            ...
# 345                    Anti-Aging
# 346                    Anti-Aging
# 347                    Anti-Aging
# 348                    Anti-Aging
# 349                           NaN
# 350                 Very Dry Skin
# 351                 Very Dry Skin
# 352                    Anti-Aging
# 353  Sensitive Skin - Calm Series
# 354                    Anti-Aging
# 355             Acne Clear Series
# 356                    Anti-Aging
# 357                Very Oily Skin
# 358                           NaN
# 359                Very Oily Skin
# 360                    Anti-Aging
# 361               Clinical Series
# 362                      Dry Skin
# 363                    Anti-Aging
# 364                    Anti-Aging
# 365                    Anti-Aging
# 366                    Anti-Aging
# 367                    Anti-Aging
# 368                           NaN
# 369                    Men Series
# 370                Very Oily Skin
# 371                    Anti-Aging
# 372                    Anti-Aging
# 373                    Anti-Aging
# 374                    Anti-Aging
#
#                                         product_handle      state  rating  \
# 0                              resist-foaming-cleanser  published       5
# 1                      resist-vitamin-c-spot-treatment  published       1
# 2        calm-redness-relief-moisturizer-normal-to-dry  published       2
# 3                     calm-redness-relief-1-bha-lotion  published       1
# 4                   skin-balancing-pore-reducing-toner  published       3
# 5    clear-regular-strength-anti-redness-exfoliatin...  published       1
# 6                  resist-moisture-renewal-oil-booster  published       2
# 7         resist-retinol-skin-smoothing-body-treatment  published       3
# 8                       resist-hyaluronic-acid-booster  published       3
# 9         skin-balancing-invisible-finish-moisture-gel  published       5
# 10                  skin-balancing-pore-reducing-toner  published       5
# 11                            resist-whitening-essence  published       5
# 12                             resist-foaming-cleanser  published       5
# 13                           skin-perfecting-2-bha-gel  published       5
# 14                 hydralight-moisture-infusing-lotion  published       5
# 15                      resist-hyaluronic-acid-booster  published       4
# 16                            resist-whitening-essence  published       4
# 17       resist-intensive-wrinkle-repair-retinol-serum  published       4
# 18             skin-perfecting-2-bha-liquid-exfoliator  published       5
# 19     resist-daily-pore-refining-treatment-with-2-bha  published       5
# 20                             resist-weightless-toner  published       5
# 21     resist-daily-pore-refining-treatment-with-2-bha  published       5
# 22   resist-ultra-light-super-antioxidant-concentra...  published       5
# 23   clear-regular-strength-daily-skin-clearing-tre...  published       5
# 24                               resist-body-oil-spray  published       4
# 25                            resist-c15-super-booster  published       5
# 26                            resist-c15-super-booster  published       4
# 27                               calmness-relief-serum  published       3
# 28                             resist-weightless-toner  published       5
# 29        skin-balancing-invisible-finish-moisture-gel  published       5
# ..                                                 ...        ...     ...
# 345                    resist-vitamin-c-spot-treatment  published       5
# 346  resist-advanced-pore-refining-treatment-4-bha-...  published       5
# 347                        resist-anti-aging-eye-cream  published       5
# 348                                       resist-bha-9  published       3
# 349                          rehydrating-moisture-mask  published       4
# 350             skin-recovery-hydrating-treatment-mask  published       5
# 351     skin-recovery-daily-moisturizing-lotion-spf-30  published       2
# 352                                       resist-bha-9  published       4
# 353                   calm-redness-relief-1-bha-lotion  published       5
# 354               resist-smoothing-primer-serum-spf-30  published       1
# 355                   clear-acne-body-spray-with-2-bha  published       3
# 356          resist-super-light-wrinkle-defense-spf-30  published       5
# 357                  skin-balancing-oil-absorbing-mask  published       4
# 358                  pore-clarifying-charcoal-gel-mask  published       2
# 359            skin-perfecting-2-bha-liquid-exfoliator  published       5
# 360                 resist-advanced-replenishing-toner  published       5
# 361     clinical-ceramide-enriched-firming-moisturizer  published       4
# 362              moisture-boost-one-step-face-cleanser  published       4
# 363          resist-super-light-wrinkle-defense-spf-30  published       5
# 364                resist-daily-mattifying-fluid-spf50  published       5
# 365                    resist-vitamin-c-spot-treatment  published       4
# 366          resist-optimal-results-hydrating-cleanser  published       4
# 367                           resist-c15-super-booster  published       4
# 368                            lip-body-treatment-balm  published       5
# 369                             pc4men-lip-balm-spf-50  published       5
# 370               skin-balancing-oil-reducing-cleanser  published       5
# 371          resist-super-light-wrinkle-defense-spf-30  published       5
# 372     resist-barrier-repair-moisturizer-with-retinol  published       5
# 373              resist-anti-aging-clear-skin-hydrator  published       3
# 374          resist-super-light-wrinkle-defense-spf-30  published       5
#
#                                                  title          author  \
# 0                                       Good cleanser          Jeannie
# 1                                            No effect             Yan
# 2                   Not Suitable for My Sensitive Skin           Linda
# 3    Does No Difference as compared to Skin Perfect...           Linda
# 4                 Stings my face after prolonged usage           Linda
# 5                                  Makes skin reactive           Linda
# 6                       Lightweight but clogs my pores           Linda
# 7                                     Does not like it           Linda
# 8                                Would not re-purchase           Linda
# 9                         Personally my HG moisturiser             Ana
# 10                            Great moisturising toner             Ana
# 11                                                 wow  YOHANA SUHARTI
# 12                                  effective cleanser          Zincky
# 13                                   excellent product          Zincky
# 14                          great for combination skin          Zincky
# 15                                       SECOND BOTTLE              GL
# 16                            HYDRATING AND CLARIFYING              GL
# 17                           Favourite nighttime serum           Dhmnj
# 18                                           Effective         Lincy36
# 19                                  Good and Effective         Lincy36
# 20                                         Great toner          Audrey
# 21                                         Works great          Audrey
# 22                                         Works great          Audrey
# 23          This always works! My holy grail for Pimps             Yan
# 24                                  Very Mositurizing              GL
# 25                     All the Vitamin C you ever need          Audrey
# 26                        Great for acne pigmentation!       Jacquelyn
# 27                                       Underwhelming             Wei
# 28                                    One of the best!       YuanJing
# 29                 Wonderful moisturizer for oily skin            CHEW
# ..                                                 ...             ...
# 345                               absolutely in love !         Ramziya
# 346    A miracle product for oily, blemish-prone skin!            Mimi
# 347                                   Great eye cream!            Mimi
# 348                                         Too drying            Mimi
# 349                           Great moisturising mask!            Mimi
# 350  The best moisturising mask (pre-makeup and whe...            Mimi
# 351                                       disappointed         Ramziya
# 352                       EFFECTIVE ON SMALL SKIN TAGS         Chimney
# 353                              Gentle but effective!         Chimney
# 354                Only works with silicone foundation            Mimi
# 355                        Works well, but the smell..            Mimi
# 356                   Best sunblock for sensitive skin          Shufen
# 357                           Good mask for oily skin!            Mimi
# 358                Good but too drying around the nose            Mimi
# 359                              Cannot do without it!          Shufen
# 360                           Great for sensitive skin         Shufen
# 361                                       Good so far!            Mimi
# 362                                 Efficient cleanser          Shufen
# 363                           Great on no makeup days!            Mimi
# 364            My daily moisturizer, great with makeup            Mimi
# 365                                             unsure              Sa
# 366     Gentle cleanser that is gd for dehydrated skin          Shufen
# 367                                       good product              Sa
# 368              Holygrail Lipblam for night time use!            Dave
# 369                         Best lip blam for day time            Dave
# 370                              Perfect for Oily Skin              SL
# 371          Awesome Sunscreen even for sensitive skin    Jaslyne Poon
# 372                     Value for money- and it works!          Shufen
# 373                Slightly drying, even for oily skin          Shufen
# 374                       Best moisturiser i have used             Kim
#
#      location                                               body  reply  \
# 0         NaN  A lotion based cleanser, slight foam. Face fee...    NaN
# 1         NaN  Unfortunately, it did not work on my pigmented...    NaN
# 2         NaN  I had wanted to transit from the Hydralight Mo...    NaN
# 3         NaN  I was previously using the Skin Perfecting 1% ...    NaN
# 4         NaN  This was the first toner I had purchased, and ...    NaN
# 5         NaN  BHA 1% is just right while BHA 2% is too stron...    NaN
# 6         NaN  I like how this feels lightweight and has no f...    NaN
# 7         NaN  I am still trying to finish it after a year.\n...    NaN
# 8         NaN  I had finished the whole bottle and does not f...    NaN
# 9         NaN  I have complicated sensitive/oily/clog-prone s...    NaN
# 10        NaN  I've been using the moisturiser from the same ...    NaN
# 11        NaN              good product  ,smooth, soft, soothing    NaN
# 12        NaN  I have combination skin, it balances my skin v...    NaN
# 13        NaN  Skin texture becomes smoother, blackheads, acn...    NaN
# 14        NaN  It solves my desquamated cheek and oily t-zone...    NaN
# 15        NaN  I mix this with c-booster and niacinamide boos...    NaN
# 16        NaN  So I tried the sample size over 3 days of appl...    NaN
# 17        NaN  This is my second bottle. I have been using th...    NaN
# 18        NaN   It is effective and mild at the same time. Sk...    NaN
# 19        NaN  Light weight and effective on acne prone skin,...    NaN
# 20        NaN  Have been using this for 1 yr. Easy to apply o...    NaN
# 21        NaN  Good for breakout prone skin. No irritation. M...    NaN
# 22        NaN  A very good serum that does not cause breakout...    NaN
# 23        NaN  This always works on my zits, red bumps or tho...    NaN
# 24        NaN  This works very well with the 10% AHA Body Exf...    NaN
# 25        NaN  Purchased the full size bottle after trying ou...    NaN
# 26        NaN  I've been using this product for about 2 month...    NaN
# 27        NaN  Leaves a sheen on my face despite being fully ...    NaN
# 28        NaN  Firstly I am a guy who have been using this fo...    NaN
# 29        NaN   absorbs quickly, and seems to help to reduce ...    NaN
# ..        ...                                                ...    ...
# 345       NaN  It was such an amazing surprise to see how bri...    NaN
# 346       NaN  I'm a big fan of the 2% BHA lotion but this pr...    NaN
# 347       NaN  I'm in my early 30s and start ed using this as...    NaN
# 348       NaN  I wish I loved this product, as I love the oth...    NaN
# 349       NaN  I have oily skin that gets dry with air-condit...    NaN
# 350       NaN  I have oily skin that gets dry with air-condit...    NaN
# 351       NaN  the only good part of it is packaging and crue...    NaN
# 352       NaN  I tried it on very small tags that cropped up ...    NaN
# 353       NaN  This did not irritate my highly sensitive skin...    NaN
# 354       NaN  I use Estee Lauder (good for oily, scarred ski...    NaN
# 355       NaN  Good product but the smell is just awful. I kn...    NaN
# 356       NaN  I have very oily and sensitive skin, this sunb...    NaN
# 357       NaN  My favourite PC mask to help clear skin while ...    NaN
# 358       NaN  This works well to unclog pores but the formul...    NaN
# 359       NaN  I use this BHA twice daily for about 2-3years ...    NaN
# 360       NaN  I have sensitive and dehydrated skin that can ...    NaN
# 361       NaN  I've only started using this a few weeks ago b...    NaN
# 362       NaN  I have very oily skin, which I double cleanse ...    NaN
# 363       NaN  I love this for the weekend, it has a nice tex...    NaN
# 364       NaN  I wear this daily under makeup and it's super ...    NaN
# 365       NaN  brightening- 100%\nfade pimple/acne scars - 10...    NaN
# 366       NaN  I have really oily skin with dehydrated surfac...    NaN
# 367       NaN  did not give as much glow as PCA's c quench. h...    NaN
# 368       NaN  This little pot helps with my lips staying hyd...    NaN
# 369       NaN  I have used up quite a few of this lip blam fo...    NaN
# 370       NaN  I love this cleanser. I use in the morning and...    NaN
# 371       NaN  Great for no makeup day! Love this so much! It...    NaN
# 372       NaN  I used to use the Resist anti-aging hydrator, ...    NaN
# 373       NaN  I found this moisturiser to be quite drying, e...    NaN
# 374       NaN  I used to have an oily and acne prone skin, ch...    NaN
#
#                   created_at  replied_at
# 0    2016-12-02 12:08:24 UTC         NaN
# 1    2016-12-03 13:26:10 UTC         NaN
# 2    2016-12-08 07:21:26 UTC         NaN
# 3    2016-12-08 07:28:12 UTC         NaN
# 4    2016-12-08 07:32:38 UTC         NaN
# 5    2016-12-08 07:35:18 UTC         NaN
# 6    2016-12-08 07:37:30 UTC         NaN
# 7    2016-12-08 07:41:19 UTC         NaN
# 8    2016-12-08 07:43:14 UTC         NaN
# 9    2016-12-11 06:23:48 UTC         NaN
# 10   2016-12-11 06:31:49 UTC         NaN
# 11   2016-12-15 09:05:08 UTC         NaN
# 12   2016-12-22 17:45:03 UTC         NaN
# 13   2016-12-22 18:12:52 UTC         NaN
# 14   2016-12-22 18:53:28 UTC         NaN
# 15   2016-12-24 15:28:20 UTC         NaN
# 16   2016-12-24 15:35:37 UTC         NaN
# 17   2016-12-24 15:51:34 UTC         NaN
# 18   2016-12-25 09:25:17 UTC         NaN
# 19   2016-12-25 09:31:39 UTC         NaN
# 20   2016-12-27 16:05:46 UTC         NaN
# 21   2016-12-27 16:10:00 UTC         NaN
# 22   2016-12-27 16:17:49 UTC         NaN
# 23   2016-12-28 08:16:36 UTC         NaN
# 24   2016-12-28 12:03:40 UTC         NaN
# 25   2016-12-29 13:35:29 UTC         NaN
# 26   2017-01-05 02:25:31 UTC         NaN
# 27   2017-01-13 01:11:15 UTC         NaN
# 28   2017-01-14 04:43:12 UTC         NaN
# 29   2017-01-23 14:24:47 UTC         NaN
# ..                       ...         ...
# 345  2018-03-06 05:12:35 UTC         NaN
# 346  2018-03-06 05:13:02 UTC         NaN
# 347  2018-03-06 05:15:56 UTC         NaN
# 348  2018-03-06 05:16:57 UTC         NaN
# 349  2018-03-06 05:20:42 UTC         NaN
# 350  2018-03-06 05:22:17 UTC         NaN
# 351  2018-03-06 05:23:32 UTC         NaN
# 352  2018-03-06 05:25:03 UTC         NaN
# 353  2018-03-06 05:26:18 UTC         NaN
# 354  2018-03-06 05:31:04 UTC         NaN
# 355  2018-03-06 05:32:30 UTC         NaN
# 356  2018-03-06 05:33:46 UTC         NaN
# 357  2018-03-06 05:34:24 UTC         NaN
# 358  2018-03-06 05:34:40 UTC         NaN
# 359  2018-03-06 05:40:04 UTC         NaN
# 360  2018-03-06 05:49:08 UTC         NaN
# 361  2018-03-06 05:52:01 UTC         NaN
# 362  2018-03-06 05:53:17 UTC         NaN
# 363  2018-03-06 05:53:26 UTC         NaN
# 364  2018-03-06 05:54:12 UTC         NaN
# 365  2018-03-06 05:57:15 UTC         NaN
# 366  2018-03-06 06:01:53 UTC         NaN
# 367  2018-03-06 06:02:41 UTC         NaN
# 368  2018-03-06 06:04:42 UTC         NaN
# 369  2018-03-06 06:06:15 UTC         NaN
# 370  2018-03-06 06:14:25 UTC         NaN
# 371  2018-03-06 06:19:23 UTC         NaN
# 372  2018-03-06 06:28:17 UTC         NaN
# 373  2018-03-06 06:34:25 UTC         NaN
# 374  2018-03-06 06:59:25 UTC         NaN
#
# [375 rows x 11 columns]

# %% [markdown]
# ## Review Rating Analysis

# %%
group_by_catgory = review['rating'].groupby(review['Category'])
for name, group in group_by_catgory:
    print name
    print group.mean()
    print group.median()
# Out:
# Acne Clear Series
# 4.15151515152
# 4.0
# Anti-Aging
# 4.36809815951
# 5.0
# Bath
# 4.66666666667
# 5.0
# Clinical Series
# 4.57142857143
# 5.0
# Combi Skin
# 4.125
# 4.0
# Dry Skin
# 4.11111111111
# 4.0
# Earth Sourced
# 4.25
# 5.0
# Men Series
# 4.72727272727
# 5.0
# Sensitive Skin - Calm Series
# 3.5
# 3.0
# Very Dry Skin
# 4.35714285714
# 5.0
# Very Oily Skin
# 4.59722222222
# 5.0

# %% [markdown]
# ## Review Topic Analysis

# %%
review['Category'].unique()
# Out:
# array([u'Anti-Aging', u'Sensitive Skin - Calm Series', u'Very Oily Skin',
#        u'Acne Clear Series', u'Combi Skin', u'Dry Skin', u'Men Series',
#        nan, u'Bath', u'Very Dry Skin', u'Clinical Series', u'Earth Sourced'], dtype=object)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from nltk import word_tokenize
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
import re
import string
#Tokenize the text
def tokenize(text):

    #Create Stemmer
    #stemmer = PorterStemmer()
    stemmer = WordNetLemmatizer()

    #Remove irrelevant character
    text = re.sub(r"[^a-zA-Z]", ' ', text)

    #Tokenization
    tokens = word_tokenize(text)
    tokens = [i for i in tokens if i not in string.punctuation]

    #Stemming
    stems = stem_tokens(tokens, stemmer)
    return stems

#Stemming Function
def stem_tokens(t,s):
    stemmed=[]
    for item in t:
        # stemmed.append(s.stem(item))
        if len(s.lemmatize(item))>2:
            stemmed.append(s.lemmatize(item))
    return stemmed

def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print message

for cat in review['Category'].unique():
    if not pd.isnull(cat):
        print cat
        lda = LatentDirichletAllocation(n_components=3, max_iter=500,
                                        learning_method='online',
                                        learning_offset=50.,
                                        random_state=0)

        tf_vectorizer = CountVectorizer(min_df=2,tokenizer = tokenize,
                                        stop_words='english')

        tf = tf_vectorizer.fit_transform(review[review['Category'] == cat]['body'])

        lda.fit(tf)
        tf_feature_names = tf_vectorizer.get_feature_names()
        print_top_words(lda, tf_feature_names, 20)
        print "\n"
# Out:
# Anti-Aging
# Topic #0: love texture product day great colour blemish makeup wish nice hide make making tint hard excellent moisturizing really little scar
# Topic #1: skin oily use feel product really bha pore eye moisturiser using sunscreen doe sensitive love tried used acne combination like
# Topic #2: skin use product try like really little just moisture day oily based good smell spot applied face cleanser size work
#
#
# Sensitive Skin - Calm Series
# Topic #0: skin using doe like sensitive product gentle moisturizer lotion kept time calming good exfoliant month feel pore better toner clogged
# Topic #1: skin dry oily face good product work breakout used got redness little moisturiser combination like tried cause time leak opened
# Topic #2: good moisturising bay use work sensitive wonder matte tried skin did absorbed definitely overall try using version breakout exfoliant time
#
#
# Very Oily Skin
# Topic #0: skin bha product sticky cleanser moisturizer feeling time control non breakout acne morning dry way don long oily type niacinamide
# Topic #1: skin use pore toner using day month moisturiser feel product help really love little time problem oily bottle face moisture
# Topic #2: skin feel bottle product make smoother great breakout used using good face help really effective work doesn makeup night remove
#
#
# Acne Clear Series
# Topic #0: acne product work month pore just face pimple really day bha time using size long skin kit oily tried buy
# Topic #1: pimple little cleanser really work skin good love feeling prefer leaf non way long tight fast don great impressed initially
# Topic #2: skin acne sensitive work dry sunscreen calm bump strong effective time day red treatment prone quite skincare using sting feel
#
#
# Combi Skin
# Topic #0: skin combination day oily product like makeup dry good cheek moisturizer feel
# Topic #1: moisturizer oily good feel skin makeup day cheek like dry combination product
# Topic #2: oily cheek dry feel good moisturizer makeup skin day combination product like
#
#
# Dry Skin
# Topic #0: skin day combination cleanser work really moisture winter use oil cleansing like used year
# Topic #1: use combination skin work winter day oil cleansing cleanser really moisture year used like
# Topic #2: year used like work cleansing oil cleanser combination day skin use winter moisture really
#
#
# Men Series
# Topic #0: product lip like bha used time day doesn shaving use cast white application second personally bought good oil daily using
# Topic #1: using daily good used product use like second tried soon buy bottle shaving application oil time personally bought cast white
# Topic #2: good oil bought personally bottle buy soon tried second like application white cast day shaving time use daily using product
#
#
# Bath
# Topic #0: dry work hair clean formula body wash shampoo
# Topic #1: hair work dry formula clean wash shampoo body
# Topic #2: clean shampoo wash body formula hair dry work
#
#
# Very Dry Skin
# Topic #0: skin use dry month feel day product mask bit weather morning long left smell face rich bottle combination leave little
# Topic #1: skin dry extremely work try great product little sensitive mask combination doe face rich red left smell bottle day feel
# Topic #2: skin time using dry clean help toner moisturiser leave bottle red doe like sensitive got use smell combination feel product
#
#
# Clinical Series
# Topic #0: skin good feel oily night moisturizer air started long product dry using week
# Topic #1: dry product air skin moisturizer night good oily feel long started week using
# Topic #2: week using long started product skin moisturizer night good air dry oily feel
#
#
# Earth Sourced
# Topic #0: product skin sensitive
# Topic #1: sensitive skin product
# Topic #2: skin product sensitive

# %%
for cat in review['rating'].unique():
    if not pd.isnull(cat):
        print cat
        lda = LatentDirichletAllocation(n_components=2, max_iter=500,
                                        learning_method='online',
                                        random_state=0)

        tf_vectorizer = CountVectorizer(min_df=2,tokenizer = tokenize,
                                        stop_words='english')

        tf = tf_vectorizer.fit_transform(review[review['rating'] == cat]['body'])

        lda.fit(tf)
        tf_feature_names = tf_vectorizer.get_feature_names()
        print_top_words(lda, tf_feature_names, 20)
        print "\n"
# Out:
# 5
# Topic #0: skin use love day makeup dry feel sunscreen product great doesn bottle clean like moisturizer little sticky long light oily
# Topic #1: skin product using pore use acne oily used moisturiser combination really month feel good work time day sensitive breakout face
#
#
# 1
# Topic #0: based work try oily skin type pimple just unfortunately use good better tried bha product bump right break caused using
# Topic #1: skin bha break product using caused right bump use tried pimple better good oily work unfortunately just try type based
#
#
# 2
# Topic #0: skin like oily little feel didnt use work heavy prefer pore broke packaging oil doesn unfortunately product good suitable doe
# Topic #1: skin product doe sensitive month like good unfortunately pore oil toner suit feel consistency lightweight really love suitable doesn packaging
#
#
# 3
# Topic #0: skin cleanser feel oily bottle sensitive work better didn gentle doe try did pretty strong exfoliator tried dry bit combination
# Topic #1: product time bha good skin dry face acne pimple pore like toner used great day really clean feeling little using
#
#
# 4
# Topic #0: skin oily feel dry oil good day try use work make like used sunscreen makeup time combination moisture face eye
# Topic #1: product skin use work bottle using acne love pore greasy really night retinol don used spot non good serum like
