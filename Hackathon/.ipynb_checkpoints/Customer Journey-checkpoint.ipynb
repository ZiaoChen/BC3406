# %% [markdown]
# # Customer Journey

# %% [markdown]
# ## Import Required Packages

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read Data (Product Specific)

# %%
events = pd.read_csv('event2.csv')
events
# Out:
#         updated_date                    event_name  \
# 0         1512697908  checkout-customer-infos-step
# 1         1512697942         checkout-payment-step
# 2         1512697983                    order-paid
# 3         1512697983            checkout-completed
# 4         1512697988                  order-create
# 5         1512707862  checkout-customer-infos-step
# 6         1512707991  checkout-customer-infos-step
# 7         1512707993               order-fulfilled
# 8         1512707993                    order-paid
# 9         1512707993                  order-create
# 10        1512707993            checkout-completed
# 11        1512708092  checkout-customer-infos-step
# 12        1512708092  checkout-customer-infos-step
# 13        1512708101         checkout-payment-step
# 14        1512708101         checkout-payment-step
# 15        1512708642                    order-paid
# 16        1512708642                    order-paid
# 17        1512708642            checkout-completed
# 18        1512708642            checkout-completed
# 19        1512708647                  order-create
# 20        1512708647                  order-create
# 21        1512709071  checkout-customer-infos-step
# 22        1512709128         checkout-payment-step
# 23        1512709310            checkout-completed
# 24        1512709310                    order-paid
# 25        1512709314                  order-create
# 26        1512710352  checkout-customer-infos-step
# 27        1512710352  checkout-customer-infos-step
# 28        1512710352  checkout-customer-infos-step
# 29        1512710352  checkout-customer-infos-step
# ...              ...                           ...
# 37696     1520490980                   update-cart
# 37697     1520490980                   update-cart
# 37698     1520490980                   update-cart
# 37699     1520490980                   update-cart
# 37700     1520490994  checkout-customer-infos-step
# 37701     1520490994  checkout-customer-infos-step
# 37702     1520490994  checkout-customer-infos-step
# 37703     1520490994  checkout-customer-infos-step
# 37704     1520491024         checkout-payment-step
# 37705     1520491024         checkout-payment-step
# 37706     1520491024         checkout-payment-step
# 37707     1520491024         checkout-payment-step
# 37708     1520491029            checkout-completed
# 37709     1520491029            checkout-completed
# 37710     1520491029            checkout-completed
# 37711     1520491029            checkout-completed
# 37712     1520491032                    order-paid
# 37713     1520491032                    order-paid
# 37714     1520491032                    order-paid
# 37715     1520491032                    order-paid
# 37716     1520491032                  order-create
# 37717     1520491032                  order-create
# 37718     1520491032                  order-create
# 37719     1520491032                  order-create
# 37720     1520491839  checkout-customer-infos-step
# 37721     1520491929            checkout-completed
# 37722     1520491929               order-fulfilled
# 37723     1520491929                    order-paid
# 37724     1520491929                  order-create
# 37725  396@email.com                    8561770567
#
#                        creation_date  completed_at  \
# 0                         1512697870           NaN
# 1                         1512697870           NaN
# 2                         1512697983           NaN
# 3                         1512697870  1.512698e+09
# 4                         1512697983           NaN
# 5                         1512707844           NaN
# 6                         1512707844           NaN
# 7                         1512707993           NaN
# 8                         1512707993           NaN
# 9                         1512707993           NaN
# 10                        1512707844  1.512708e+09
# 11                        1512625845           NaN
# 12                        1512625845           NaN
# 13                        1512625845           NaN
# 14                        1512625845           NaN
# 15                        1512708642           NaN
# 16                        1512708642           NaN
# 17                        1512625845  1.512709e+09
# 18                        1512625845  1.512709e+09
# 19                        1512708642           NaN
# 20                        1512708642           NaN
# 21                        1512708702           NaN
# 22                        1512708702           NaN
# 23                        1512708702  1.512709e+09
# 24                        1512709310           NaN
# 25                        1512709310           NaN
# 26                        1512710288           NaN
# 27                        1512710288           NaN
# 28                        1512710288           NaN
# 29                        1512710288           NaN
# ...                              ...           ...
# 37696                     1520490667           NaN
# 37697                     1520490667           NaN
# 37698                     1520490667           NaN
# 37699                     1520490667           NaN
# 37700                     1520490927           NaN
# 37701                     1520490927           NaN
# 37702                     1520490927           NaN
# 37703                     1520490927           NaN
# 37704                     1520490927           NaN
# 37705                     1520490927           NaN
# 37706                     1520490927           NaN
# 37707                     1520490927           NaN
# 37708                     1520490927  1.520491e+09
# 37709                     1520490927  1.520491e+09
# 37710                     1520490927  1.520491e+09
# 37711                     1520490927  1.520491e+09
# 37712                     1520491027           NaN
# 37713                     1520491027           NaN
# 37714                     1520491027           NaN
# 37715                     1520491027           NaN
# 37716                     1520491027           NaN
# 37717                     1520491027           NaN
# 37718                     1520491027           NaN
# 37719                     1520491027           NaN
# 37720                     1520491819           NaN
# 37721                     1520491819  1.520492e+09
# 37722                     1520491928           NaN
# 37723                     1520491928           NaN
# 37724                     1520491928           NaN
# 37725  Resist BHA 9 (Salicylic Acid)  1.400000e+03
#
#                               total_discounts    order_number  \
# 0                                         NaN   #212626636819
# 1                                         NaN   #212626636819
# 2                                         NaN    191569912821
# 3                                         NaN   #212626636819
# 4                                         NaN    191569912821
# 5                                         NaN   #213026832403
# 6                                         NaN   #213026832403
# 7                                         NaN    191569912823
# 8                                         NaN    191569912823
# 9                                         NaN    191569912823
# 10                                        NaN   #213026832403
# 11                                        NaN   #208976347155
# 12                                        NaN   #208976347155
# 13                                        NaN   #208976347155
# 14                                        NaN   #208976347155
# 15                                        NaN    191569912826
# 16                                        NaN    191569912826
# 17                                        NaN   #208976347155
# 18                                        NaN   #208976347155
# 19                                        NaN    191569912826
# 20                                        NaN    191569912826
# 21                                        NaN   #213053833235
# 22                                        NaN   #213053833235
# 23                                        NaN   #213053833235
# 24                                        NaN    191569912827
# 25                                        NaN    191569912827
# 26                                        NaN   #213104033811
# 27                                        NaN   #213104033811
# 28                                        NaN   #213104033811
# 29                                        NaN   #213104033811
# ...                                       ...             ...
# 37696                                     NaN             NaN
# 37697                                     NaN             NaN
# 37698                                     NaN             NaN
# 37699                                     NaN             NaN
# 37700  {u'currency': u'SGD', u'amount': 2500}  #2489129631809
# 37701  {u'currency': u'SGD', u'amount': 2500}  #2489129631809
# 37702  {u'currency': u'SGD', u'amount': 2500}  #2489129631809
# 37703  {u'currency': u'SGD', u'amount': 2500}  #2489129631809
# 37704  {u'currency': u'SGD', u'amount': 2500}  #2489129631809
# 37705  {u'currency': u'SGD', u'amount': 2500}  #2489129631809
# 37706  {u'currency': u'SGD', u'amount': 2500}  #2489129631809
# 37707  {u'currency': u'SGD', u'amount': 2500}  #2489129631809
# 37708  {u'currency': u'SGD', u'amount': 2500}  #2489129631809
# 37709  {u'currency': u'SGD', u'amount': 2500}  #2489129631809
# 37710  {u'currency': u'SGD', u'amount': 2500}  #2489129631809
# 37711  {u'currency': u'SGD', u'amount': 2500}  #2489129631809
# 37712  {u'currency': u'SGD', u'amount': 2500}    191569915715
# 37713  {u'currency': u'SGD', u'amount': 2500}    191569915715
# 37714  {u'currency': u'SGD', u'amount': 2500}    191569915715
# 37715  {u'currency': u'SGD', u'amount': 2500}    191569915715
# 37716  {u'currency': u'SGD', u'amount': 2500}    191569915715
# 37717  {u'currency': u'SGD', u'amount': 2500}    191569915715
# 37718  {u'currency': u'SGD', u'amount': 2500}    191569915715
# 37719  {u'currency': u'SGD', u'amount': 2500}    191569915715
# 37720                                     NaN  #2489154666561
# 37721                                     NaN  #2489154666561
# 37722                                     NaN    191569915716
# 37723                                     NaN    191569915716
# 37724                                     NaN    191569915716
# 37725                                     NaN               7
#
#                                      id processing_method total_price  \
# 0                          212627000000               NaN        8800
# 1                          212627000000               NaN        8800
# 2                           89274286099            direct        8800
# 3                          212627000000               NaN        8800
# 4                           89274286099            direct        8800
# 5                          213027000000               NaN        8600
# 6                          213027000000               NaN        8600
# 7                           89458769939   external-credit        8600
# 8                           89458769939   external-credit        8600
# 9                           89458769939   external-credit        8600
# 10                         213027000000               NaN        8600
# 11                         208976000000               NaN        9100
# 12                         208976000000               NaN        9100
# 13                         208976000000               NaN        9100
# 14                         208976000000               NaN        9100
# 15                          89466667027            direct        9100
# 16                          89466667027            direct        9100
# 17                         208976000000               NaN        9100
# 18                         208976000000               NaN        9100
# 19                          89466667027            direct        9100
# 20                          89466667027            direct        9100
# 21                         213054000000               NaN       15600
# 22                         213054000000               NaN       15600
# 23                         213054000000               NaN       15600
# 24                          89475579923            direct       15600
# 25                          89475579923            direct       15600
# 26                         213104000000               NaN       13800
# 27                         213104000000               NaN       13800
# 28                         213104000000               NaN       13800
# 29                         213104000000               NaN       13800
# ...                                 ...               ...         ...
# 37696  a2f6be55064efd7aecf37a4cb14d02ed               NaN         NaN
# 37697  a2f6be55064efd7aecf37a4cb14d02ed               NaN         NaN
# 37698  a2f6be55064efd7aecf37a4cb14d02ed               NaN         NaN
# 37699  a2f6be55064efd7aecf37a4cb14d02ed               NaN         NaN
# 37700                     2489130000000               NaN       10500
# 37701                     2489130000000               NaN       10500
# 37702                     2489130000000               NaN       10500
# 37703                     2489130000000               NaN       10500
# 37704                     2489130000000               NaN       10500
# 37705                     2489130000000               NaN       10500
# 37706                     2489130000000               NaN       10500
# 37707                     2489130000000               NaN       10500
# 37708                     2489130000000               NaN       10500
# 37709                     2489130000000               NaN       10500
# 37710                     2489130000000               NaN       10500
# 37711                     2489130000000               NaN       10500
# 37712                      368514000000            direct       10500
# 37713                      368514000000            direct       10500
# 37714                      368514000000            direct       10500
# 37715                      368514000000            direct       10500
# 37716                      368514000000            direct       10500
# 37717                      368514000000            direct       10500
# 37718                      368514000000            direct       10500
# 37719                      368514000000            direct       10500
# 37720                     2489150000000               NaN        6100
# 37721                     2489150000000               NaN        6100
# 37722                      368517000000    external-debit        6100
# 37723                      368517000000    external-debit        6100
# 37724                      368517000000    external-debit        6100
# 37725                              7739               NaN         NaN
#
#            user_id     ...              gateway  \
# 0      4.39866e+09     ...                  NaN
# 1      4.39866e+09     ...                  NaN
# 2      4.39866e+09     ...               stripe
# 3      4.39866e+09     ...               stripe
# 4      4.39866e+09     ...               stripe
# 5      4.39856e+09     ...                  NaN
# 6      4.39856e+09     ...      external-credit
# 7      4.39856e+09     ...      external-credit
# 8      4.39856e+09     ...      external-credit
# 9      4.39856e+09     ...      external-credit
# 10     4.39856e+09     ...      external-credit
# 11      9.7605e+10     ...                  NaN
# 12      9.7605e+10     ...                  NaN
# 13      9.7605e+10     ...                  NaN
# 14      9.7605e+10     ...                  NaN
# 15      9.7605e+10     ...               stripe
# 16      9.7605e+10     ...               stripe
# 17      9.7605e+10     ...               stripe
# 18      9.7605e+10     ...               stripe
# 19      9.7605e+10     ...               stripe
# 20      9.7605e+10     ...               stripe
# 21     9.76191e+10     ...                  NaN
# 22     9.76191e+10     ...                  NaN
# 23     9.76191e+10     ...               stripe
# 24     9.76191e+10     ...               stripe
# 25     9.76191e+10     ...               stripe
# 26     5.68478e+09     ...                  NaN
# 27     5.68478e+09     ...                  NaN
# 28     5.68478e+09     ...                  NaN
# 29     5.68478e+09     ...                  NaN
# ...            ...     ...                  ...
# 37696   5818300679     ...                  NaN
# 37697   5818300679     ...                  NaN
# 37698   5818300679     ...                  NaN
# 37699   5818300679     ...                  NaN
# 37700   5818300679     ...                  NaN
# 37701   5818300679     ...                  NaN
# 37702   5818300679     ...                  NaN
# 37703   5818300679     ...                  NaN
# 37704   5818300679     ...                  NaN
# 37705   5818300679     ...                  NaN
# 37706   5818300679     ...                  NaN
# 37707   5818300679     ...                  NaN
# 37708   5818300679     ...               stripe
# 37709   5818300679     ...               stripe
# 37710   5818300679     ...               stripe
# 37711   5818300679     ...               stripe
# 37712   5818300679     ...               stripe
# 37713   5818300679     ...               stripe
# 37714   5818300679     ...               stripe
# 37715   5818300679     ...               stripe
# 37716   5818300679     ...               stripe
# 37717   5818300679     ...               stripe
# 37718   5818300679     ...               stripe
# 37719   5818300679     ...               stripe
# 37720   6443070675     ...                  NaN
# 37721   6443070675     ...       external-debit
# 37722   6443070675     ...       external-debit
# 37723   6443070675     ...       external-debit
# 37724   6443070675     ...       external-debit
# 37725          NaN     ...                  NaN
#
#                                   abandoned_checkout_url  \
# 0      https://checkout.shopify.com/14402440/checkout...
# 1      https://checkout.shopify.com/14402440/checkout...
# 2                                                    NaN
# 3      https://checkout.shopify.com/14402440/checkout...
# 4                                                    NaN
# 5      https://checkout.shopify.com/14402440/checkout...
# 6      https://checkout.shopify.com/14402440/checkout...
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10     https://checkout.shopify.com/14402440/checkout...
# 11     https://checkout.shopify.com/14402440/checkout...
# 12     https://checkout.shopify.com/14402440/checkout...
# 13     https://checkout.shopify.com/14402440/checkout...
# 14     https://checkout.shopify.com/14402440/checkout...
# 15                                                   NaN
# 16                                                   NaN
# 17     https://checkout.shopify.com/14402440/checkout...
# 18     https://checkout.shopify.com/14402440/checkout...
# 19                                                   NaN
# 20                                                   NaN
# 21     https://checkout.shopify.com/14402440/checkout...
# 22     https://checkout.shopify.com/14402440/checkout...
# 23     https://checkout.shopify.com/14402440/checkout...
# 24                                                   NaN
# 25                                                   NaN
# 26     https://checkout.shopify.com/14402440/checkout...
# 27     https://checkout.shopify.com/14402440/checkout...
# 28     https://checkout.shopify.com/14402440/checkout...
# 29     https://checkout.shopify.com/14402440/checkout...
# ...                                                  ...
# 37696                                                NaN
# 37697                                                NaN
# 37698                                                NaN
# 37699                                                NaN
# 37700  https://checkout.shopify.com/14402440/checkout...
# 37701  https://checkout.shopify.com/14402440/checkout...
# 37702  https://checkout.shopify.com/14402440/checkout...
# 37703  https://checkout.shopify.com/14402440/checkout...
# 37704  https://checkout.shopify.com/14402440/checkout...
# 37705  https://checkout.shopify.com/14402440/checkout...
# 37706  https://checkout.shopify.com/14402440/checkout...
# 37707  https://checkout.shopify.com/14402440/checkout...
# 37708  https://checkout.shopify.com/14402440/checkout...
# 37709  https://checkout.shopify.com/14402440/checkout...
# 37710  https://checkout.shopify.com/14402440/checkout...
# 37711  https://checkout.shopify.com/14402440/checkout...
# 37712                                                NaN
# 37713                                                NaN
# 37714                                                NaN
# 37715                                                NaN
# 37716                                                NaN
# 37717                                                NaN
# 37718                                                NaN
# 37719                                                NaN
# 37720  https://checkout.shopify.com/14402440/checkout...
# 37721  https://checkout.shopify.com/14402440/checkout...
# 37722                                                NaN
# 37723                                                NaN
# 37724                                                NaN
# 37725                                                NaN
#
#                intercom_user_id                   email   product_id  \
# 0      5a2233b89bdbb3db0c165793   customer849@email.com   9386653255
# 1      5a2233b89bdbb3db0c165793   customer849@email.com   9386653255
# 2      5a2233b89bdbb3db0c165793   customer849@email.com   9386653255
# 3      5a2233b89bdbb3db0c165793   customer849@email.com   9386653255
# 4      5a2233b89bdbb3db0c165793   customer849@email.com   9386653255
# 5      5a2a171a6fe23bd05f9e31ed  customer1377@email.com   8561792135
# 6      5a2a171a6fe23bd05f9e31ed  customer1377@email.com   8561792135
# 7      5a2a171a6fe23bd05f9e31ed  customer1377@email.com   8561792135
# 8      5a2a171a6fe23bd05f9e31ed  customer1377@email.com   8561792135
# 9      5a2a171a6fe23bd05f9e31ed  customer1377@email.com   8561792135
# 10     5a2a171a6fe23bd05f9e31ed  customer1377@email.com   8561792135
# 11     5a2a17fdd9032809f25e5558  customer1375@email.com   8561713031
# 12     5a2a17fdd9032809f25e5558  customer1375@email.com   8561784903
# 13     5a2a17fdd9032809f25e5558  customer1375@email.com   8561713031
# 14     5a2a17fdd9032809f25e5558  customer1375@email.com   8561784903
# 15     5a2a17fdd9032809f25e5558  customer1375@email.com   8561713031
# 16     5a2a17fdd9032809f25e5558  customer1375@email.com   8561784903
# 17     5a2a17fdd9032809f25e5558  customer1375@email.com   8561713031
# 18     5a2a17fdd9032809f25e5558  customer1375@email.com   8561784903
# 19     5a2a17fdd9032809f25e5558  customer1375@email.com   8561713031
# 20     5a2a17fdd9032809f25e5558  customer1375@email.com   8561784903
# 21     5a2a1bcf96e2639d41f00fb4   customer901@email.com   9386224903
# 22     5a2a1bcf96e2639d41f00fb4   customer901@email.com   9386224903
# 23     5a2a1bcf96e2639d41f00fb4   customer901@email.com   9386224903
# 24     5a2a1bcf96e2639d41f00fb4   customer901@email.com   9386224903
# 25     5a2a1bcf96e2639d41f00fb4   customer901@email.com   9386224903
# 26     59357a81395b7b0af3c1e8d7  customer1374@email.com   8561862407
# 27     59357a81395b7b0af3c1e8d7  customer1374@email.com   8561898183
# 28     59357a81395b7b0af3c1e8d7  customer1374@email.com   8561821895
# 29     59357a81395b7b0af3c1e8d7  customer1374@email.com   8561902279
# ...                         ...                     ...          ...
# 37696  5955299a2f95a37888f1b9ea   customer668@email.com  85234155539
# 37697  5955299a2f95a37888f1b9ea   customer668@email.com   9123729095
# 37698  5955299a2f95a37888f1b9ea   customer668@email.com   8561681223
# 37699  5955299a2f95a37888f1b9ea   customer668@email.com   8561828487
# 37700  5955299a2f95a37888f1b9ea   customer668@email.com  85234155539
# 37701  5955299a2f95a37888f1b9ea   customer668@email.com   9123729095
# 37702  5955299a2f95a37888f1b9ea   customer668@email.com   8561681223
# 37703  5955299a2f95a37888f1b9ea   customer668@email.com   8561828487
# 37704  5955299a2f95a37888f1b9ea   customer668@email.com  85234155539
# 37705  5955299a2f95a37888f1b9ea   customer668@email.com   9123729095
# 37706  5955299a2f95a37888f1b9ea   customer668@email.com   8561681223
# 37707  5955299a2f95a37888f1b9ea   customer668@email.com   8561828487
# 37708  5955299a2f95a37888f1b9ea   customer668@email.com  85234155539
# 37709  5955299a2f95a37888f1b9ea   customer668@email.com   9123729095
# 37710  5955299a2f95a37888f1b9ea   customer668@email.com   8561681223
# 37711  5955299a2f95a37888f1b9ea   customer668@email.com   8561828487
# 37712  5955299a2f95a37888f1b9ea   customer668@email.com  85234155539
# 37713  5955299a2f95a37888f1b9ea   customer668@email.com   9123729095
# 37714  5955299a2f95a37888f1b9ea   customer668@email.com   8561681223
# 37715  5955299a2f95a37888f1b9ea   customer668@email.com   8561828487
# 37716  5955299a2f95a37888f1b9ea   customer668@email.com  85234155539
# 37717  5955299a2f95a37888f1b9ea   customer668@email.com   9123729095
# 37718  5955299a2f95a37888f1b9ea   customer668@email.com   8561681223
# 37719  5955299a2f95a37888f1b9ea   customer668@email.com   8561828487
# 37720  59354a96d163cc0de49cff7a   customer640@email.com   8561770567
# 37721  59354a96d163cc0de49cff7a   customer640@email.com   8561770567
# 37722  59354a96d163cc0de49cff7a   customer640@email.com   8561770567
# 37723  59354a96d163cc0de49cff7a   customer640@email.com   8561770567
# 37724  59354a96d163cc0de49cff7a   customer640@email.com   8561770567
# 37725                       NaN                     NaN          NaN
#
#                                            product_title product_price  \
# 0      Resist Skin Resurfacing + Smoothing Exfoliant Kit          8800
# 1      Resist Skin Resurfacing + Smoothing Exfoliant Kit          8800
# 2      Resist Skin Resurfacing + Smoothing Exfoliant Kit          8800
# 3      Resist Skin Resurfacing + Smoothing Exfoliant Kit          8800
# 4      Resist Skin Resurfacing + Smoothing Exfoliant Kit          8800
# 5      Skin Perfecting 2% BHA (Salicylic Acid) Liquid...          4300
# 6      Skin Perfecting 2% BHA (Salicylic Acid) Liquid...          4300
# 7      Skin Perfecting 2% BHA (Salicylic Acid) Liquid...          4300
# 8      Skin Perfecting 2% BHA (Salicylic Acid) Liquid...          4300
# 9      Skin Perfecting 2% BHA (Salicylic Acid) Liquid...          4300
# 10     Skin Perfecting 2% BHA (Salicylic Acid) Liquid...          4300
# 11        Resist Barrier Repair Moisturizer with Retinol          4800
# 12     Clear Acne Extra Strength Exfoliating Treatmen...          4300
# 13        Resist Barrier Repair Moisturizer with Retinol          4800
# 14     Clear Acne Extra Strength Exfoliating Treatmen...          4300
# 15        Resist Barrier Repair Moisturizer with Retinol          4800
# 16     Clear Acne Extra Strength Exfoliating Treatmen...          4300
# 17        Resist Barrier Repair Moisturizer with Retinol          4800
# 18     Clear Acne Extra Strength Exfoliating Treatmen...          4300
# 19        Resist Barrier Repair Moisturizer with Retinol          4800
# 20     Clear Acne Extra Strength Exfoliating Treatmen...          4300
# 21                                  PC4Men Essential Kit         15600
# 22                                  PC4Men Essential Kit         15600
# 23                                  PC4Men Essential Kit         15600
# 24                                  PC4Men Essential Kit         15600
# 25                                  PC4Men Essential Kit         15600
# 26     Resist Youth-Extending Daily Hydrating Fluid S...          4800
# 27            Resist Intensive Repair Cream with Retinol          4800
# 28             Resist Optimal Results Hydrating Cleanser          1500
# 29                   Resist 25% Vitamin C Spot Treatment          2700
# ...                                                  ...           ...
# 37696          Rehydrating Moisture Mask - Sachet Bundle             5
# 37697             Radiance Renewal Whitening Mask - 10ml            15
# 37698  Resist Daily Pore-Refining Treatment 2% BHA (S...            15
# 37699      Skin Balancing Oil-Reducing Cleanser - 473 ml            50
# 37700                          Rehydrating Moisture Mask           500
# 37701                    Radiance Renewal Whitening Mask          1500
# 37702  Resist Daily Pore-Refining Treatment 2% BHA (S...          1500
# 37703               Skin Balancing Oil-Reducing Cleanser          5000
# 37704                          Rehydrating Moisture Mask           500
# 37705                    Radiance Renewal Whitening Mask          1500
# 37706  Resist Daily Pore-Refining Treatment 2% BHA (S...          1500
# 37707               Skin Balancing Oil-Reducing Cleanser          5000
# 37708                          Rehydrating Moisture Mask           500
# 37709                    Radiance Renewal Whitening Mask          1500
# 37710  Resist Daily Pore-Refining Treatment 2% BHA (S...          1500
# 37711               Skin Balancing Oil-Reducing Cleanser          5000
# 37712                          Rehydrating Moisture Mask           500
# 37713                    Radiance Renewal Whitening Mask          1500
# 37714  Resist Daily Pore-Refining Treatment 2% BHA (S...          1500
# 37715               Skin Balancing Oil-Reducing Cleanser          5000
# 37716                          Rehydrating Moisture Mask           500
# 37717                    Radiance Renewal Whitening Mask          1500
# 37718  Resist Daily Pore-Refining Treatment 2% BHA (S...          1500
# 37719               Skin Balancing Oil-Reducing Cleanser          5000
# 37720                      Resist BHA 9 (Salicylic Acid)          6100
# 37721                      Resist BHA 9 (Salicylic Acid)          6100
# 37722                      Resist BHA 9 (Salicylic Acid)          6100
# 37723                      Resist BHA 9 (Salicylic Acid)          6100
# 37724                      Resist BHA 9 (Salicylic Acid)          6100
# 37725                                                NaN           NaN
#
#       product_status product_grams product_sku
# 0                NaN           NaN        4850
# 1                NaN           NaN        4850
# 2                NaN           NaN        4850
# 3                NaN           NaN        4850
# 4                NaN           NaN        4850
# 5                NaN           158        2010
# 6                NaN           158        2010
# 7          fulfilled           158        2010
# 8                NaN           158        2010
# 9                NaN           158        2010
# 10               NaN           158        2010
# 11               NaN           111        7610
# 12               NaN           144        6210
# 13               NaN           111        7610
# 14               NaN           144        6210
# 15               NaN           111        7610
# 16               NaN           144        6210
# 17               NaN           111        7610
# 18               NaN           144        6210
# 19               NaN           111        7610
# 20               NaN           144        6210
# 21               NaN           NaN        4950
# 22               NaN           NaN        4950
# 23               NaN           NaN        4950
# 24               NaN           NaN        4950
# 25               NaN           NaN        4950
# 26               NaN            73        7800
# 27               NaN           106        7810
# 28               NaN            41        7607
# 29               NaN            14        7857
# ...              ...           ...         ...
# 37696            NaN           NaN        2607
# 37697            NaN           NaN        2777
# 37698            NaN            43        7827
# 37699            NaN           532        1151
# 37700            NaN           NaN        2607
# 37701            NaN           NaN        2777
# 37702            NaN            43        7827
# 37703            NaN           532        1151
# 37704            NaN           NaN        2607
# 37705            NaN           NaN        2777
# 37706            NaN            43        7827
# 37707            NaN           532        1151
# 37708            NaN           NaN        2607
# 37709            NaN           NaN        2777
# 37710            NaN            43        7827
# 37711            NaN           532        1151
# 37712            NaN           NaN        2607
# 37713            NaN           NaN        2777
# 37714            NaN            43        7827
# 37715            NaN           532        1151
# 37716            NaN           NaN        2607
# 37717            NaN           NaN        2777
# 37718            NaN            43        7827
# 37719            NaN           532        1151
# 37720            NaN            33        7730
# 37721            NaN            33        7730
# 37722      fulfilled            33        7730
# 37723      fulfilled            33        7730
# 37724            NaN            33        7730
# 37725            NaN           NaN         NaN
#
# [37726 rows x 21 columns]

# %% [markdown]
# ## Get Order Specific Data

# %%
orders = events
drop_columns = ['product_title','product_id','product_price','product_status','product_grams','product_sku']
orders = orders.drop(drop_columns, axis=1)
print orders.shape
orders = orders.drop_duplicates()
print orders.shape
orders = orders[pd.notnull(orders['user_id'])]
print orders.shape
orders
# Out:
# (37726, 15)
# (16956, 15)
# (16946, 15)
#       updated_date                    event_name creation_date  completed_at  \
# 0       1512697908  checkout-customer-infos-step    1512697870           NaN
# 1       1512697942         checkout-payment-step    1512697870           NaN
# 2       1512697983                    order-paid    1512697983           NaN
# 3       1512697983            checkout-completed    1512697870  1.512698e+09
# 4       1512697988                  order-create    1512697983           NaN
# 5       1512707862  checkout-customer-infos-step    1512707844           NaN
# 6       1512707991  checkout-customer-infos-step    1512707844           NaN
# 7       1512707993               order-fulfilled    1512707993           NaN
# 8       1512707993                    order-paid    1512707993           NaN
# 9       1512707993                  order-create    1512707993           NaN
# 10      1512707993            checkout-completed    1512707844  1.512708e+09
# 11      1512708092  checkout-customer-infos-step    1512625845           NaN
# 13      1512708101         checkout-payment-step    1512625845           NaN
# 15      1512708642                    order-paid    1512708642           NaN
# 17      1512708642            checkout-completed    1512625845  1.512709e+09
# 19      1512708647                  order-create    1512708642           NaN
# 21      1512709071  checkout-customer-infos-step    1512708702           NaN
# 22      1512709128         checkout-payment-step    1512708702           NaN
# 23      1512709310            checkout-completed    1512708702  1.512709e+09
# 24      1512709310                    order-paid    1512709310           NaN
# 25      1512709314                  order-create    1512709310           NaN
# 26      1512710352  checkout-customer-infos-step    1512710288           NaN
# 30      1512710513                   update-cart    1512709247           NaN
# 34      1512710513  checkout-customer-infos-step    1512710288           NaN
# 38      1512710520  checkout-customer-infos-step    1512710288           NaN
# 42      1512710543         checkout-payment-step    1512710288           NaN
# 46      1512710646                    order-paid    1512710646           NaN
# 50      1512710647            checkout-completed    1512710288  1.512711e+09
# 54      1512710648                  order-create    1512710646           NaN
# 58      1512711217                   create-cart    1512711217           NaN
# ...            ...                           ...           ...           ...
# 37658   1520488310               order-fulfilled    1520347932           NaN
# 37659   1520488587  checkout-customer-infos-step    1520488557           NaN
# 37661   1520488609                   create-cart    1520488609           NaN
# 37663   1520488630         checkout-payment-step    1520488557           NaN
# 37665   1520488635                   update-cart    1520488390           NaN
# 37667   1520488640               order-fulfilled    1520255317           NaN
# 37669   1520488852         checkout-payment-step    1520488557           NaN
# 37671   1520489306         checkout-payment-step    1520488557           NaN
# 37673   1520489920                   update-cart    1520488609           NaN
# 37675   1520489921  checkout-customer-infos-step    1520423311           NaN
# 37677   1520490634         checkout-payment-step    1520423311           NaN
# 37679   1520490662                    order-paid    1520490657           NaN
# 37681   1520490662                  order-create    1520490657           NaN
# 37683   1520490662            checkout-completed    1520423311  1.520491e+09
# 37685   1520490843                   update-cart    1520490843           NaN
# 37686   1520490843                   create-cart    1520490843           NaN
# 37687   1520490913                   update-cart    1520490667           NaN
# 37690   1520490927                checkout-start    1520490927           NaN
# 37693   1520490932  checkout-customer-infos-step    1520490927           NaN
# 37696   1520490980                   update-cart    1520490667           NaN
# 37700   1520490994  checkout-customer-infos-step    1520490927           NaN
# 37704   1520491024         checkout-payment-step    1520490927           NaN
# 37708   1520491029            checkout-completed    1520490927  1.520491e+09
# 37712   1520491032                    order-paid    1520491027           NaN
# 37716   1520491032                  order-create    1520491027           NaN
# 37720   1520491839  checkout-customer-infos-step    1520491819           NaN
# 37721   1520491929            checkout-completed    1520491819  1.520492e+09
# 37722   1520491929               order-fulfilled    1520491928           NaN
# 37723   1520491929                    order-paid    1520491928           NaN
# 37724   1520491929                  order-create    1520491928           NaN
#
#                               total_discounts    order_number  \
# 0                                         NaN   #212626636819
# 1                                         NaN   #212626636819
# 2                                         NaN    191569912821
# 3                                         NaN   #212626636819
# 4                                         NaN    191569912821
# 5                                         NaN   #213026832403
# 6                                         NaN   #213026832403
# 7                                         NaN    191569912823
# 8                                         NaN    191569912823
# 9                                         NaN    191569912823
# 10                                        NaN   #213026832403
# 11                                        NaN   #208976347155
# 13                                        NaN   #208976347155
# 15                                        NaN    191569912826
# 17                                        NaN   #208976347155
# 19                                        NaN    191569912826
# 21                                        NaN   #213053833235
# 22                                        NaN   #213053833235
# 23                                        NaN   #213053833235
# 24                                        NaN    191569912827
# 25                                        NaN    191569912827
# 26                                        NaN   #213104033811
# 30                                        NaN             NaN
# 34                                        NaN   #213104033811
# 38     {u'currency': u'SGD', u'amount': 1000}   #213104033811
# 42     {u'currency': u'SGD', u'amount': 1000}   #213104033811
# 46     {u'currency': u'SGD', u'amount': 1000}    191569912828
# 50     {u'currency': u'SGD', u'amount': 1000}   #213104033811
# 54     {u'currency': u'SGD', u'amount': 1000}    191569912828
# 58                                        NaN             NaN
# ...                                       ...             ...
# 37658                                     NaN    191569915668
# 37659                                     NaN  #2489065144385
# 37661                                     NaN             NaN
# 37663                                     NaN  #2489065144385
# 37665                                     NaN             NaN
# 37667   {u'currency': u'SGD', u'amount': 500}    191569915609
# 37669                                     NaN  #2489065144385
# 37671                                     NaN  #2489065144385
# 37673                                     NaN             NaN
# 37675                                     NaN  #2486940368961
# 37677                                     NaN  #2486940368961
# 37679                                     NaN    191569915714
# 37681                                     NaN    191569915714
# 37683                                     NaN  #2486940368961
# 37685                                     NaN             NaN
# 37686                                     NaN             NaN
# 37687                                     NaN             NaN
# 37690                                     NaN  #2489129631809
# 37693  {u'currency': u'SGD', u'amount': 2500}  #2489129631809
# 37696                                     NaN             NaN
# 37700  {u'currency': u'SGD', u'amount': 2500}  #2489129631809
# 37704  {u'currency': u'SGD', u'amount': 2500}  #2489129631809
# 37708  {u'currency': u'SGD', u'amount': 2500}  #2489129631809
# 37712  {u'currency': u'SGD', u'amount': 2500}    191569915715
# 37716  {u'currency': u'SGD', u'amount': 2500}    191569915715
# 37720                                     NaN  #2489154666561
# 37721                                     NaN  #2489154666561
# 37722                                     NaN    191569915716
# 37723                                     NaN    191569915716
# 37724                                     NaN    191569915716
#
#                                      id processing_method total_price  \
# 0                          212627000000               NaN        8800
# 1                          212627000000               NaN        8800
# 2                           89274286099            direct        8800
# 3                          212627000000               NaN        8800
# 4                           89274286099            direct        8800
# 5                          213027000000               NaN        8600
# 6                          213027000000               NaN        8600
# 7                           89458769939   external-credit        8600
# 8                           89458769939   external-credit        8600
# 9                           89458769939   external-credit        8600
# 10                         213027000000               NaN        8600
# 11                         208976000000               NaN        9100
# 13                         208976000000               NaN        9100
# 15                          89466667027            direct        9100
# 17                         208976000000               NaN        9100
# 19                          89466667027            direct        9100
# 21                         213054000000               NaN       15600
# 22                         213054000000               NaN       15600
# 23                         213054000000               NaN       15600
# 24                          89475579923            direct       15600
# 25                          89475579923            direct       15600
# 26                         213104000000               NaN       13800
# 30     81b7630c9d3ad032c1f73d60bc9a1680               NaN         NaN
# 34                         213104000000               NaN       13800
# 38                         213104000000               NaN       12800
# 42                         213104000000               NaN       12800
# 46                          89491472403            direct       12800
# 50                         213104000000               NaN       12800
# 54                          89491472403            direct       12800
# 58     100abd5c13057a52463a6af2b8c52072               NaN         NaN
# ...                                 ...               ...         ...
# 37658                      367770000000            direct        4300
# 37659                     2489070000000               NaN        8600
# 37661  47e0fc38d2d56f831161452a73937326               NaN         NaN
# 37663                     2489070000000               NaN        8600
# 37665  2454ae27f743f6b0680f3cd7468a470b               NaN         NaN
# 37667                      367391000000            direct        9100
# 37669                     2489070000000               NaN        8600
# 37671                     2489070000000               NaN        8600
# 37673  47e0fc38d2d56f831161452a73937326               NaN         NaN
# 37675                     2486940000000               NaN        7700
# 37677                     2486940000000               NaN        7700
# 37679                      368513000000            direct        7700
# 37681                      368513000000            direct        7700
# 37683                     2486940000000               NaN        7700
# 37685  7dbedd650daea0a94f3ee71d5e93b967               NaN         NaN
# 37686  7dbedd650daea0a94f3ee71d5e93b967               NaN         NaN
# 37687  a2f6be55064efd7aecf37a4cb14d02ed               NaN         NaN
# 37690                     2489130000000               NaN       12500
# 37693                     2489130000000               NaN       10000
# 37696  a2f6be55064efd7aecf37a4cb14d02ed               NaN         NaN
# 37700                     2489130000000               NaN       10500
# 37704                     2489130000000               NaN       10500
# 37708                     2489130000000               NaN       10500
# 37712                      368514000000            direct       10500
# 37716                      368514000000            direct       10500
# 37720                     2489150000000               NaN        6100
# 37721                     2489150000000               NaN        6100
# 37722                      368517000000    external-debit        6100
# 37723                      368517000000    external-debit        6100
# 37724                      368517000000    external-debit        6100
#
#            user_id  created_at          gateway  \
# 0      4.39866e+09  1512697908              NaN
# 1      4.39866e+09  1512697942              NaN
# 2      4.39866e+09  1512697983           stripe
# 3      4.39866e+09  1512697983           stripe
# 4      4.39866e+09  1512697988           stripe
# 5      4.39856e+09  1512707862              NaN
# 6      4.39856e+09  1512707991  external-credit
# 7      4.39856e+09  1512707993  external-credit
# 8      4.39856e+09  1512707993  external-credit
# 9      4.39856e+09  1512707993  external-credit
# 10     4.39856e+09  1512707993  external-credit
# 11      9.7605e+10  1512708092              NaN
# 13      9.7605e+10  1512708101              NaN
# 15      9.7605e+10  1512708642           stripe
# 17      9.7605e+10  1512708642           stripe
# 19      9.7605e+10  1512708647           stripe
# 21     9.76191e+10  1512709071              NaN
# 22     9.76191e+10  1512709128              NaN
# 23     9.76191e+10  1512709310           stripe
# 24     9.76191e+10  1512709310           stripe
# 25     9.76191e+10  1512709314           stripe
# 26     5.68478e+09  1512710352              NaN
# 30     5.68478e+09  1512710513              NaN
# 34     5.68478e+09  1512710513              NaN
# 38     5.68478e+09  1512710520              NaN
# 42     5.68478e+09  1512710543              NaN
# 46     5.68478e+09  1512710646           stripe
# 50     5.68478e+09  1512710647           stripe
# 54     5.68478e+09  1512710648           stripe
# 58     9.76191e+10  1512711217              NaN
# ...            ...         ...              ...
# 37658   4398626695  1520488310           stripe
# 37659   4398559751  1520488587              NaN
# 37661   4398836295  1520488609              NaN
# 37663   4398559751  1520488630              NaN
# 37665   4398559751  1520488635              NaN
# 37667   6591506195  1520488640           stripe
# 37669   4398559751  1520488852              NaN
# 37671   4398559751  1520489306              NaN
# 37673   4398836295  1520489920              NaN
# 37675   4398836295  1520489921              NaN
# 37677   4398836295  1520490634              NaN
# 37679   4398836295  1520490662           stripe
# 37681   4398836295  1520490662           stripe
# 37683   4398836295  1520490662           stripe
# 37685   4398717639  1520490843              NaN
# 37686   4398717639  1520490843              NaN
# 37687   5818300679  1520490913              NaN
# 37690   5818300679  1520490927              NaN
# 37693   5818300679  1520490932              NaN
# 37696   5818300679  1520490980              NaN
# 37700   5818300679  1520490994              NaN
# 37704   5818300679  1520491024              NaN
# 37708   5818300679  1520491029           stripe
# 37712   5818300679  1520491032           stripe
# 37716   5818300679  1520491032           stripe
# 37720   6443070675  1520491839              NaN
# 37721   6443070675  1520491929   external-debit
# 37722   6443070675  1520491929   external-debit
# 37723   6443070675  1520491929   external-debit
# 37724   6443070675  1520491929   external-debit
#
#                                   abandoned_checkout_url  \
# 0      https://checkout.shopify.com/14402440/checkout...
# 1      https://checkout.shopify.com/14402440/checkout...
# 2                                                    NaN
# 3      https://checkout.shopify.com/14402440/checkout...
# 4                                                    NaN
# 5      https://checkout.shopify.com/14402440/checkout...
# 6      https://checkout.shopify.com/14402440/checkout...
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10     https://checkout.shopify.com/14402440/checkout...
# 11     https://checkout.shopify.com/14402440/checkout...
# 13     https://checkout.shopify.com/14402440/checkout...
# 15                                                   NaN
# 17     https://checkout.shopify.com/14402440/checkout...
# 19                                                   NaN
# 21     https://checkout.shopify.com/14402440/checkout...
# 22     https://checkout.shopify.com/14402440/checkout...
# 23     https://checkout.shopify.com/14402440/checkout...
# 24                                                   NaN
# 25                                                   NaN
# 26     https://checkout.shopify.com/14402440/checkout...
# 30                                                   NaN
# 34     https://checkout.shopify.com/14402440/checkout...
# 38     https://checkout.shopify.com/14402440/checkout...
# 42     https://checkout.shopify.com/14402440/checkout...
# 46                                                   NaN
# 50     https://checkout.shopify.com/14402440/checkout...
# 54                                                   NaN
# 58                                                   NaN
# ...                                                  ...
# 37658                                                NaN
# 37659  https://checkout.shopify.com/14402440/checkout...
# 37661                                                NaN
# 37663  https://checkout.shopify.com/14402440/checkout...
# 37665                                                NaN
# 37667                                                NaN
# 37669  https://checkout.shopify.com/14402440/checkout...
# 37671  https://checkout.shopify.com/14402440/checkout...
# 37673                                                NaN
# 37675  https://checkout.shopify.com/14402440/checkout...
# 37677  https://checkout.shopify.com/14402440/checkout...
# 37679                                                NaN
# 37681                                                NaN
# 37683  https://checkout.shopify.com/14402440/checkout...
# 37685                                                NaN
# 37686                                                NaN
# 37687                                                NaN
# 37690  https://checkout.shopify.com/14402440/checkout...
# 37693  https://checkout.shopify.com/14402440/checkout...
# 37696                                                NaN
# 37700  https://checkout.shopify.com/14402440/checkout...
# 37704  https://checkout.shopify.com/14402440/checkout...
# 37708  https://checkout.shopify.com/14402440/checkout...
# 37712                                                NaN
# 37716                                                NaN
# 37720  https://checkout.shopify.com/14402440/checkout...
# 37721  https://checkout.shopify.com/14402440/checkout...
# 37722                                                NaN
# 37723                                                NaN
# 37724                                                NaN
#
#                intercom_user_id                   email
# 0      5a2233b89bdbb3db0c165793   customer849@email.com
# 1      5a2233b89bdbb3db0c165793   customer849@email.com
# 2      5a2233b89bdbb3db0c165793   customer849@email.com
# 3      5a2233b89bdbb3db0c165793   customer849@email.com
# 4      5a2233b89bdbb3db0c165793   customer849@email.com
# 5      5a2a171a6fe23bd05f9e31ed  customer1377@email.com
# 6      5a2a171a6fe23bd05f9e31ed  customer1377@email.com
# 7      5a2a171a6fe23bd05f9e31ed  customer1377@email.com
# 8      5a2a171a6fe23bd05f9e31ed  customer1377@email.com
# 9      5a2a171a6fe23bd05f9e31ed  customer1377@email.com
# 10     5a2a171a6fe23bd05f9e31ed  customer1377@email.com
# 11     5a2a17fdd9032809f25e5558  customer1375@email.com
# 13     5a2a17fdd9032809f25e5558  customer1375@email.com
# 15     5a2a17fdd9032809f25e5558  customer1375@email.com
# 17     5a2a17fdd9032809f25e5558  customer1375@email.com
# 19     5a2a17fdd9032809f25e5558  customer1375@email.com
# 21     5a2a1bcf96e2639d41f00fb4   customer901@email.com
# 22     5a2a1bcf96e2639d41f00fb4   customer901@email.com
# 23     5a2a1bcf96e2639d41f00fb4   customer901@email.com
# 24     5a2a1bcf96e2639d41f00fb4   customer901@email.com
# 25     5a2a1bcf96e2639d41f00fb4   customer901@email.com
# 26     59357a81395b7b0af3c1e8d7  customer1374@email.com
# 30     59357a81395b7b0af3c1e8d7  customer1374@email.com
# 34     59357a81395b7b0af3c1e8d7  customer1374@email.com
# 38     59357a81395b7b0af3c1e8d7  customer1374@email.com
# 42     59357a81395b7b0af3c1e8d7  customer1374@email.com
# 46     59357a81395b7b0af3c1e8d7  customer1374@email.com
# 50     59357a81395b7b0af3c1e8d7  customer1374@email.com
# 54     59357a81395b7b0af3c1e8d7  customer1374@email.com
# 58     5a2a1bcf96e2639d41f00fb4   customer901@email.com
# ...                         ...                     ...
# 37658  59b7f1db01e1945c8246211c  customer4612@email.com
# 37659  5941f98b3d65c177d61557bd   customer730@email.com
# 37661  593b5520629d8d698d7968d3  customer1552@email.com
# 37663  5941f98b3d65c177d61557bd   customer730@email.com
# 37665  5941f98b3d65c177d61557bd   customer730@email.com
# 37667  59354a2fe99d750df59d5238   customer344@email.com
# 37669  5941f98b3d65c177d61557bd   customer730@email.com
# 37671  5941f98b3d65c177d61557bd   customer730@email.com
# 37673  593b5520629d8d698d7968d3  customer1552@email.com
# 37675  593b5520629d8d698d7968d3  customer1552@email.com
# 37677  593b5520629d8d698d7968d3  customer1552@email.com
# 37679  593b5520629d8d698d7968d3  customer1552@email.com
# 37681  593b5520629d8d698d7968d3  customer1552@email.com
# 37683  593b5520629d8d698d7968d3  customer1552@email.com
# 37685  59b503db7116bbf6612d18b5  customer2579@email.com
# 37686  59b503db7116bbf6612d18b5  customer2579@email.com
# 37687  5955299a2f95a37888f1b9ea   customer668@email.com
# 37690  5955299a2f95a37888f1b9ea   customer668@email.com
# 37693  5955299a2f95a37888f1b9ea   customer668@email.com
# 37696  5955299a2f95a37888f1b9ea   customer668@email.com
# 37700  5955299a2f95a37888f1b9ea   customer668@email.com
# 37704  5955299a2f95a37888f1b9ea   customer668@email.com
# 37708  5955299a2f95a37888f1b9ea   customer668@email.com
# 37712  5955299a2f95a37888f1b9ea   customer668@email.com
# 37716  5955299a2f95a37888f1b9ea   customer668@email.com
# 37720  59354a96d163cc0de49cff7a   customer640@email.com
# 37721  59354a96d163cc0de49cff7a   customer640@email.com
# 37722  59354a96d163cc0de49cff7a   customer640@email.com
# 37723  59354a96d163cc0de49cff7a   customer640@email.com
# 37724  59354a96d163cc0de49cff7a   customer640@email.com
#
# [16946 rows x 15 columns]

# %% [markdown]
# ## Add Back Discount (check out price change even if same order)

# %%
import ast
def add_back_discount(row):
    if not pd.isnull(row['total_discounts']):
        row['total_price'] = float(float(row['total_price']) + float(ast.literal_eval(row['total_discounts'])['amount']))
    return row
orders = orders.apply(add_back_discount,axis=1)
orders
# Out:
#       updated_date                    event_name creation_date  completed_at  \
# 0       1512697908  checkout-customer-infos-step    1512697870           NaN
# 1       1512697942         checkout-payment-step    1512697870           NaN
# 2       1512697983                    order-paid    1512697983           NaN
# 3       1512697983            checkout-completed    1512697870  1.512698e+09
# 4       1512697988                  order-create    1512697983           NaN
# 5       1512707862  checkout-customer-infos-step    1512707844           NaN
# 6       1512707991  checkout-customer-infos-step    1512707844           NaN
# 7       1512707993               order-fulfilled    1512707993           NaN
# 8       1512707993                    order-paid    1512707993           NaN
# 9       1512707993                  order-create    1512707993           NaN
# 10      1512707993            checkout-completed    1512707844  1.512708e+09
# 11      1512708092  checkout-customer-infos-step    1512625845           NaN
# 13      1512708101         checkout-payment-step    1512625845           NaN
# 15      1512708642                    order-paid    1512708642           NaN
# 17      1512708642            checkout-completed    1512625845  1.512709e+09
# 19      1512708647                  order-create    1512708642           NaN
# 21      1512709071  checkout-customer-infos-step    1512708702           NaN
# 22      1512709128         checkout-payment-step    1512708702           NaN
# 23      1512709310            checkout-completed    1512708702  1.512709e+09
# 24      1512709310                    order-paid    1512709310           NaN
# 25      1512709314                  order-create    1512709310           NaN
# 26      1512710352  checkout-customer-infos-step    1512710288           NaN
# 30      1512710513                   update-cart    1512709247           NaN
# 34      1512710513  checkout-customer-infos-step    1512710288           NaN
# 38      1512710520  checkout-customer-infos-step    1512710288           NaN
# 42      1512710543         checkout-payment-step    1512710288           NaN
# 46      1512710646                    order-paid    1512710646           NaN
# 50      1512710647            checkout-completed    1512710288  1.512711e+09
# 54      1512710648                  order-create    1512710646           NaN
# 58      1512711217                   create-cart    1512711217           NaN
# ...            ...                           ...           ...           ...
# 37658   1520488310               order-fulfilled    1520347932           NaN
# 37659   1520488587  checkout-customer-infos-step    1520488557           NaN
# 37661   1520488609                   create-cart    1520488609           NaN
# 37663   1520488630         checkout-payment-step    1520488557           NaN
# 37665   1520488635                   update-cart    1520488390           NaN
# 37667   1520488640               order-fulfilled    1520255317           NaN
# 37669   1520488852         checkout-payment-step    1520488557           NaN
# 37671   1520489306         checkout-payment-step    1520488557           NaN
# 37673   1520489920                   update-cart    1520488609           NaN
# 37675   1520489921  checkout-customer-infos-step    1520423311           NaN
# 37677   1520490634         checkout-payment-step    1520423311           NaN
# 37679   1520490662                    order-paid    1520490657           NaN
# 37681   1520490662                  order-create    1520490657           NaN
# 37683   1520490662            checkout-completed    1520423311  1.520491e+09
# 37685   1520490843                   update-cart    1520490843           NaN
# 37686   1520490843                   create-cart    1520490843           NaN
# 37687   1520490913                   update-cart    1520490667           NaN
# 37690   1520490927                checkout-start    1520490927           NaN
# 37693   1520490932  checkout-customer-infos-step    1520490927           NaN
# 37696   1520490980                   update-cart    1520490667           NaN
# 37700   1520490994  checkout-customer-infos-step    1520490927           NaN
# 37704   1520491024         checkout-payment-step    1520490927           NaN
# 37708   1520491029            checkout-completed    1520490927  1.520491e+09
# 37712   1520491032                    order-paid    1520491027           NaN
# 37716   1520491032                  order-create    1520491027           NaN
# 37720   1520491839  checkout-customer-infos-step    1520491819           NaN
# 37721   1520491929            checkout-completed    1520491819  1.520492e+09
# 37722   1520491929               order-fulfilled    1520491928           NaN
# 37723   1520491929                    order-paid    1520491928           NaN
# 37724   1520491929                  order-create    1520491928           NaN
#
#                               total_discounts    order_number  \
# 0                                         NaN   #212626636819
# 1                                         NaN   #212626636819
# 2                                         NaN    191569912821
# 3                                         NaN   #212626636819
# 4                                         NaN    191569912821
# 5                                         NaN   #213026832403
# 6                                         NaN   #213026832403
# 7                                         NaN    191569912823
# 8                                         NaN    191569912823
# 9                                         NaN    191569912823
# 10                                        NaN   #213026832403
# 11                                        NaN   #208976347155
# 13                                        NaN   #208976347155
# 15                                        NaN    191569912826
# 17                                        NaN   #208976347155
# 19                                        NaN    191569912826
# 21                                        NaN   #213053833235
# 22                                        NaN   #213053833235
# 23                                        NaN   #213053833235
# 24                                        NaN    191569912827
# 25                                        NaN    191569912827
# 26                                        NaN   #213104033811
# 30                                        NaN             NaN
# 34                                        NaN   #213104033811
# 38     {u'currency': u'SGD', u'amount': 1000}   #213104033811
# 42     {u'currency': u'SGD', u'amount': 1000}   #213104033811
# 46     {u'currency': u'SGD', u'amount': 1000}    191569912828
# 50     {u'currency': u'SGD', u'amount': 1000}   #213104033811
# 54     {u'currency': u'SGD', u'amount': 1000}    191569912828
# 58                                        NaN             NaN
# ...                                       ...             ...
# 37658                                     NaN    191569915668
# 37659                                     NaN  #2489065144385
# 37661                                     NaN             NaN
# 37663                                     NaN  #2489065144385
# 37665                                     NaN             NaN
# 37667   {u'currency': u'SGD', u'amount': 500}    191569915609
# 37669                                     NaN  #2489065144385
# 37671                                     NaN  #2489065144385
# 37673                                     NaN             NaN
# 37675                                     NaN  #2486940368961
# 37677                                     NaN  #2486940368961
# 37679                                     NaN    191569915714
# 37681                                     NaN    191569915714
# 37683                                     NaN  #2486940368961
# 37685                                     NaN             NaN
# 37686                                     NaN             NaN
# 37687                                     NaN             NaN
# 37690                                     NaN  #2489129631809
# 37693  {u'currency': u'SGD', u'amount': 2500}  #2489129631809
# 37696                                     NaN             NaN
# 37700  {u'currency': u'SGD', u'amount': 2500}  #2489129631809
# 37704  {u'currency': u'SGD', u'amount': 2500}  #2489129631809
# 37708  {u'currency': u'SGD', u'amount': 2500}  #2489129631809
# 37712  {u'currency': u'SGD', u'amount': 2500}    191569915715
# 37716  {u'currency': u'SGD', u'amount': 2500}    191569915715
# 37720                                     NaN  #2489154666561
# 37721                                     NaN  #2489154666561
# 37722                                     NaN    191569915716
# 37723                                     NaN    191569915716
# 37724                                     NaN    191569915716
#
#                                      id processing_method total_price  \
# 0                          212627000000               NaN        8800
# 1                          212627000000               NaN        8800
# 2                           89274286099            direct        8800
# 3                          212627000000               NaN        8800
# 4                           89274286099            direct        8800
# 5                          213027000000               NaN        8600
# 6                          213027000000               NaN        8600
# 7                           89458769939   external-credit        8600
# 8                           89458769939   external-credit        8600
# 9                           89458769939   external-credit        8600
# 10                         213027000000               NaN        8600
# 11                         208976000000               NaN        9100
# 13                         208976000000               NaN        9100
# 15                          89466667027            direct        9100
# 17                         208976000000               NaN        9100
# 19                          89466667027            direct        9100
# 21                         213054000000               NaN       15600
# 22                         213054000000               NaN       15600
# 23                         213054000000               NaN       15600
# 24                          89475579923            direct       15600
# 25                          89475579923            direct       15600
# 26                         213104000000               NaN       13800
# 30     81b7630c9d3ad032c1f73d60bc9a1680               NaN         NaN
# 34                         213104000000               NaN       13800
# 38                         213104000000               NaN       13800
# 42                         213104000000               NaN       13800
# 46                          89491472403            direct       13800
# 50                         213104000000               NaN       13800
# 54                          89491472403            direct       13800
# 58     100abd5c13057a52463a6af2b8c52072               NaN         NaN
# ...                                 ...               ...         ...
# 37658                      367770000000            direct        4300
# 37659                     2489070000000               NaN        8600
# 37661  47e0fc38d2d56f831161452a73937326               NaN         NaN
# 37663                     2489070000000               NaN        8600
# 37665  2454ae27f743f6b0680f3cd7468a470b               NaN         NaN
# 37667                      367391000000            direct        9600
# 37669                     2489070000000               NaN        8600
# 37671                     2489070000000               NaN        8600
# 37673  47e0fc38d2d56f831161452a73937326               NaN         NaN
# 37675                     2486940000000               NaN        7700
# 37677                     2486940000000               NaN        7700
# 37679                      368513000000            direct        7700
# 37681                      368513000000            direct        7700
# 37683                     2486940000000               NaN        7700
# 37685  7dbedd650daea0a94f3ee71d5e93b967               NaN         NaN
# 37686  7dbedd650daea0a94f3ee71d5e93b967               NaN         NaN
# 37687  a2f6be55064efd7aecf37a4cb14d02ed               NaN         NaN
# 37690                     2489130000000               NaN       12500
# 37693                     2489130000000               NaN       12500
# 37696  a2f6be55064efd7aecf37a4cb14d02ed               NaN         NaN
# 37700                     2489130000000               NaN       13000
# 37704                     2489130000000               NaN       13000
# 37708                     2489130000000               NaN       13000
# 37712                      368514000000            direct       13000
# 37716                      368514000000            direct       13000
# 37720                     2489150000000               NaN        6100
# 37721                     2489150000000               NaN        6100
# 37722                      368517000000    external-debit        6100
# 37723                      368517000000    external-debit        6100
# 37724                      368517000000    external-debit        6100
#
#            user_id  created_at          gateway  \
# 0      4.39866e+09  1512697908              NaN
# 1      4.39866e+09  1512697942              NaN
# 2      4.39866e+09  1512697983           stripe
# 3      4.39866e+09  1512697983           stripe
# 4      4.39866e+09  1512697988           stripe
# 5      4.39856e+09  1512707862              NaN
# 6      4.39856e+09  1512707991  external-credit
# 7      4.39856e+09  1512707993  external-credit
# 8      4.39856e+09  1512707993  external-credit
# 9      4.39856e+09  1512707993  external-credit
# 10     4.39856e+09  1512707993  external-credit
# 11      9.7605e+10  1512708092              NaN
# 13      9.7605e+10  1512708101              NaN
# 15      9.7605e+10  1512708642           stripe
# 17      9.7605e+10  1512708642           stripe
# 19      9.7605e+10  1512708647           stripe
# 21     9.76191e+10  1512709071              NaN
# 22     9.76191e+10  1512709128              NaN
# 23     9.76191e+10  1512709310           stripe
# 24     9.76191e+10  1512709310           stripe
# 25     9.76191e+10  1512709314           stripe
# 26     5.68478e+09  1512710352              NaN
# 30     5.68478e+09  1512710513              NaN
# 34     5.68478e+09  1512710513              NaN
# 38     5.68478e+09  1512710520              NaN
# 42     5.68478e+09  1512710543              NaN
# 46     5.68478e+09  1512710646           stripe
# 50     5.68478e+09  1512710647           stripe
# 54     5.68478e+09  1512710648           stripe
# 58     9.76191e+10  1512711217              NaN
# ...            ...         ...              ...
# 37658   4398626695  1520488310           stripe
# 37659   4398559751  1520488587              NaN
# 37661   4398836295  1520488609              NaN
# 37663   4398559751  1520488630              NaN
# 37665   4398559751  1520488635              NaN
# 37667   6591506195  1520488640           stripe
# 37669   4398559751  1520488852              NaN
# 37671   4398559751  1520489306              NaN
# 37673   4398836295  1520489920              NaN
# 37675   4398836295  1520489921              NaN
# 37677   4398836295  1520490634              NaN
# 37679   4398836295  1520490662           stripe
# 37681   4398836295  1520490662           stripe
# 37683   4398836295  1520490662           stripe
# 37685   4398717639  1520490843              NaN
# 37686   4398717639  1520490843              NaN
# 37687   5818300679  1520490913              NaN
# 37690   5818300679  1520490927              NaN
# 37693   5818300679  1520490932              NaN
# 37696   5818300679  1520490980              NaN
# 37700   5818300679  1520490994              NaN
# 37704   5818300679  1520491024              NaN
# 37708   5818300679  1520491029           stripe
# 37712   5818300679  1520491032           stripe
# 37716   5818300679  1520491032           stripe
# 37720   6443070675  1520491839              NaN
# 37721   6443070675  1520491929   external-debit
# 37722   6443070675  1520491929   external-debit
# 37723   6443070675  1520491929   external-debit
# 37724   6443070675  1520491929   external-debit
#
#                                   abandoned_checkout_url  \
# 0      https://checkout.shopify.com/14402440/checkout...
# 1      https://checkout.shopify.com/14402440/checkout...
# 2                                                    NaN
# 3      https://checkout.shopify.com/14402440/checkout...
# 4                                                    NaN
# 5      https://checkout.shopify.com/14402440/checkout...
# 6      https://checkout.shopify.com/14402440/checkout...
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10     https://checkout.shopify.com/14402440/checkout...
# 11     https://checkout.shopify.com/14402440/checkout...
# 13     https://checkout.shopify.com/14402440/checkout...
# 15                                                   NaN
# 17     https://checkout.shopify.com/14402440/checkout...
# 19                                                   NaN
# 21     https://checkout.shopify.com/14402440/checkout...
# 22     https://checkout.shopify.com/14402440/checkout...
# 23     https://checkout.shopify.com/14402440/checkout...
# 24                                                   NaN
# 25                                                   NaN
# 26     https://checkout.shopify.com/14402440/checkout...
# 30                                                   NaN
# 34     https://checkout.shopify.com/14402440/checkout...
# 38     https://checkout.shopify.com/14402440/checkout...
# 42     https://checkout.shopify.com/14402440/checkout...
# 46                                                   NaN
# 50     https://checkout.shopify.com/14402440/checkout...
# 54                                                   NaN
# 58                                                   NaN
# ...                                                  ...
# 37658                                                NaN
# 37659  https://checkout.shopify.com/14402440/checkout...
# 37661                                                NaN
# 37663  https://checkout.shopify.com/14402440/checkout...
# 37665                                                NaN
# 37667                                                NaN
# 37669  https://checkout.shopify.com/14402440/checkout...
# 37671  https://checkout.shopify.com/14402440/checkout...
# 37673                                                NaN
# 37675  https://checkout.shopify.com/14402440/checkout...
# 37677  https://checkout.shopify.com/14402440/checkout...
# 37679                                                NaN
# 37681                                                NaN
# 37683  https://checkout.shopify.com/14402440/checkout...
# 37685                                                NaN
# 37686                                                NaN
# 37687                                                NaN
# 37690  https://checkout.shopify.com/14402440/checkout...
# 37693  https://checkout.shopify.com/14402440/checkout...
# 37696                                                NaN
# 37700  https://checkout.shopify.com/14402440/checkout...
# 37704  https://checkout.shopify.com/14402440/checkout...
# 37708  https://checkout.shopify.com/14402440/checkout...
# 37712                                                NaN
# 37716                                                NaN
# 37720  https://checkout.shopify.com/14402440/checkout...
# 37721  https://checkout.shopify.com/14402440/checkout...
# 37722                                                NaN
# 37723                                                NaN
# 37724                                                NaN
#
#                intercom_user_id                   email
# 0      5a2233b89bdbb3db0c165793   customer849@email.com
# 1      5a2233b89bdbb3db0c165793   customer849@email.com
# 2      5a2233b89bdbb3db0c165793   customer849@email.com
# 3      5a2233b89bdbb3db0c165793   customer849@email.com
# 4      5a2233b89bdbb3db0c165793   customer849@email.com
# 5      5a2a171a6fe23bd05f9e31ed  customer1377@email.com
# 6      5a2a171a6fe23bd05f9e31ed  customer1377@email.com
# 7      5a2a171a6fe23bd05f9e31ed  customer1377@email.com
# 8      5a2a171a6fe23bd05f9e31ed  customer1377@email.com
# 9      5a2a171a6fe23bd05f9e31ed  customer1377@email.com
# 10     5a2a171a6fe23bd05f9e31ed  customer1377@email.com
# 11     5a2a17fdd9032809f25e5558  customer1375@email.com
# 13     5a2a17fdd9032809f25e5558  customer1375@email.com
# 15     5a2a17fdd9032809f25e5558  customer1375@email.com
# 17     5a2a17fdd9032809f25e5558  customer1375@email.com
# 19     5a2a17fdd9032809f25e5558  customer1375@email.com
# 21     5a2a1bcf96e2639d41f00fb4   customer901@email.com
# 22     5a2a1bcf96e2639d41f00fb4   customer901@email.com
# 23     5a2a1bcf96e2639d41f00fb4   customer901@email.com
# 24     5a2a1bcf96e2639d41f00fb4   customer901@email.com
# 25     5a2a1bcf96e2639d41f00fb4   customer901@email.com
# 26     59357a81395b7b0af3c1e8d7  customer1374@email.com
# 30     59357a81395b7b0af3c1e8d7  customer1374@email.com
# 34     59357a81395b7b0af3c1e8d7  customer1374@email.com
# 38     59357a81395b7b0af3c1e8d7  customer1374@email.com
# 42     59357a81395b7b0af3c1e8d7  customer1374@email.com
# 46     59357a81395b7b0af3c1e8d7  customer1374@email.com
# 50     59357a81395b7b0af3c1e8d7  customer1374@email.com
# 54     59357a81395b7b0af3c1e8d7  customer1374@email.com
# 58     5a2a1bcf96e2639d41f00fb4   customer901@email.com
# ...                         ...                     ...
# 37658  59b7f1db01e1945c8246211c  customer4612@email.com
# 37659  5941f98b3d65c177d61557bd   customer730@email.com
# 37661  593b5520629d8d698d7968d3  customer1552@email.com
# 37663  5941f98b3d65c177d61557bd   customer730@email.com
# 37665  5941f98b3d65c177d61557bd   customer730@email.com
# 37667  59354a2fe99d750df59d5238   customer344@email.com
# 37669  5941f98b3d65c177d61557bd   customer730@email.com
# 37671  5941f98b3d65c177d61557bd   customer730@email.com
# 37673  593b5520629d8d698d7968d3  customer1552@email.com
# 37675  593b5520629d8d698d7968d3  customer1552@email.com
# 37677  593b5520629d8d698d7968d3  customer1552@email.com
# 37679  593b5520629d8d698d7968d3  customer1552@email.com
# 37681  593b5520629d8d698d7968d3  customer1552@email.com
# 37683  593b5520629d8d698d7968d3  customer1552@email.com
# 37685  59b503db7116bbf6612d18b5  customer2579@email.com
# 37686  59b503db7116bbf6612d18b5  customer2579@email.com
# 37687  5955299a2f95a37888f1b9ea   customer668@email.com
# 37690  5955299a2f95a37888f1b9ea   customer668@email.com
# 37693  5955299a2f95a37888f1b9ea   customer668@email.com
# 37696  5955299a2f95a37888f1b9ea   customer668@email.com
# 37700  5955299a2f95a37888f1b9ea   customer668@email.com
# 37704  5955299a2f95a37888f1b9ea   customer668@email.com
# 37708  5955299a2f95a37888f1b9ea   customer668@email.com
# 37712  5955299a2f95a37888f1b9ea   customer668@email.com
# 37716  5955299a2f95a37888f1b9ea   customer668@email.com
# 37720  59354a96d163cc0de49cff7a   customer640@email.com
# 37721  59354a96d163cc0de49cff7a   customer640@email.com
# 37722  59354a96d163cc0de49cff7a   customer640@email.com
# 37723  59354a96d163cc0de49cff7a   customer640@email.com
# 37724  59354a96d163cc0de49cff7a   customer640@email.com
#
# [16946 rows x 15 columns]

# %% [markdown]
# ## Sort Orders

# %%
orders = orders.sort_values(['user_id', 'created_at'], ascending=[True, True])
orders.to_csv('cleaned_events.csv')

# %% [markdown]
# ## Impute Total Price

# %%
previous_price = 0
def impute_total_price(val):
    global previous_price
    if pd.isnull(val):
        return previous_price
    else:
        previous_price = val
        return val

orders["total_price"] = orders["total_price"][::-1].apply(lambda x: impute_total_price(x))
orders["total_price"] = orders["total_price"][::-1]
orders
# Out:
#       updated_date                    event_name creation_date  completed_at  \
# 20921   1517020064                   create-cart    1517020064           NaN
# 20922   1517020065                   update-cart    1517020064           NaN
# 20923   1517020149                   update-cart    1517020064           NaN
# 20925   1517020474                   update-cart    1517020064           NaN
# 21199   1517033172                checkout-start    1517033172           NaN
# 21202   1517033172  checkout-customer-infos-step    1517033172           NaN
# 21205   1517033195         checkout-payment-step    1517033172           NaN
# 21596   1517066945                   update-cart    1517020064           NaN
# 21608   1517067225                   update-cart    1517020064           NaN
# 21611   1517067316                   update-cart    1517020064           NaN
# 21613   1517067383                   update-cart    1517020064           NaN
# 21626   1517067920         checkout-payment-step    1517033172           NaN
# 21629   1517067970                  order-create    1517067968           NaN
# 21632   1517067970                    order-paid    1517067968           NaN
# 21635   1517067971            checkout-completed    1517033172  1.517068e+09
# 22563   1517236053               order-fulfilled    1517067968           NaN
# 7399    1513939724                    order-paid    1513939724           NaN
# 7400    1513939724                  order-create    1513939724           NaN
# 7401    1513939724               order-fulfilled    1513939724           NaN
# 22780   1517289557                   create-cart    1517289557           NaN
# 22781   1517289562                   update-cart    1517289557           NaN
# 22782   1517289562                checkout-start    1517289562           NaN
# 22783   1517289571  checkout-customer-infos-step    1517289562           NaN
# 32439   1519220139                   create-cart    1519220139           NaN
# 32671   1519287838                   update-cart    1519287169           NaN
# 3222    1513244608  checkout-customer-infos-step    1513244592           NaN
# 3256    1513244773         checkout-payment-step    1513244592           NaN
# 3260    1513244947            checkout-completed    1513244592  1.513245e+09
# 3262    1513244947                    order-paid    1513244947           NaN
# 3264    1513244952                  order-create    1513244947           NaN
# ...            ...                           ...           ...           ...
# 35412   1519913625  checkout-customer-infos-step    1519913551           NaN
# 35413   1519913633         checkout-payment-step    1519913551           NaN
# 35414   1519913683                   update-cart    1519913543           NaN
# 35415   1519913767         checkout-payment-step    1519913551           NaN
# 35416   1519913817            checkout-completed    1519913551  1.519914e+09
# 35417   1519913822                    order-paid    1519913815           NaN
# 35418   1519913822                  order-create    1519913815           NaN
# 35536   1519986483               order-fulfilled    1519913815           NaN
# 34376   1519699518                   create-cart    1519699518           NaN
# 34377   1519699520                   update-cart    1519699518           NaN
# 34378   1519699555                checkout-start    1519699555           NaN
# 34379   1519699556  checkout-customer-infos-step    1519699555           NaN
# 34380   1519699583         checkout-payment-step    1519699555           NaN
# 34381   1519699592         checkout-payment-step    1519699555           NaN
# 34382   1519699675            checkout-completed    1519699555  1.519700e+09
# 34383   1519699678                    order-paid    1519699671           NaN
# 34384   1519699678                  order-create    1519699671           NaN
# 34557   1519731745               order-fulfilled    1519699671           NaN
# 34915   1519806620                   create-cart    1519806620           NaN
# 34916   1519806626                   update-cart    1519806620           NaN
# 34917   1519806698                   update-cart    1519806620           NaN
# 34919   1519806699  checkout-customer-infos-step    1519806699           NaN
# 34921   1519806699                checkout-start    1519806699           NaN
# 34923   1519806868         checkout-payment-step    1519806699           NaN
# 34969   1519818641            checkout-completed    1519806699  1.519819e+09
# 34971   1519818645                  order-create    1519818639           NaN
# 34973   1519818645                    order-paid    1519818639           NaN
# 35508   1519968908               order-fulfilled    1519818639           NaN
# 35517   1519973222                  order-create    1519973218           NaN
# 35538   1519986547               order-fulfilled    1519973218           NaN
#
#                               total_discounts    order_number  \
# 20921                                     NaN             nan
# 20922                                     NaN             nan
# 20923                                     NaN             nan
# 20925                                     NaN             nan
# 21199                                     NaN   #524617154579
# 21202                                     NaN   #524617154579
# 21205                                     NaN   #524617154579
# 21596                                     NaN             nan
# 21608                                     NaN             nan
# 21611                                     NaN             nan
# 21613                                     NaN             nan
# 21626  {u'currency': u'SGD', u'amount': 1500}   #524617154579
# 21629  {u'currency': u'SGD', u'amount': 1500}    191569914330
# 21632  {u'currency': u'SGD', u'amount': 1500}    191569914330
# 21635  {u'currency': u'SGD', u'amount': 1500}   #524617154579
# 22563  {u'currency': u'SGD', u'amount': 1500}    191569914330
# 7399                                      NaN  191569910-1503
# 7400                                      NaN  191569910-1503
# 7401                                      NaN  191569910-1503
# 22780                                     NaN             nan
# 22781                                     NaN             nan
# 22782                                     NaN   #534257270803
# 22783  {u'currency': u'SGD', u'amount': 1000}   #534257270803
# 32439                                     NaN             nan
# 32671                                     NaN             nan
# 3222                                      NaN   #241440653331
# 3256                                      NaN   #241440653331
# 3260                                      NaN   #241440653331
# 3262                                      NaN    191569913042
# 3264                                      NaN    191569913042
# ...                                       ...             ...
# 35412                                     NaN  #2479944892481
# 35413                                     NaN  #2479944892481
# 35414                                     NaN             nan
# 35415  {u'currency': u'SGD', u'amount': 1500}  #2479944892481
# 35416  {u'currency': u'SGD', u'amount': 1500}  #2479944892481
# 35417  {u'currency': u'SGD', u'amount': 1500}    191569915477
# 35418  {u'currency': u'SGD', u'amount': 1500}    191569915477
# 35536  {u'currency': u'SGD', u'amount': 1500}    191569915477
# 34376                                     NaN             nan
# 34377                                     NaN             nan
# 34378                                     NaN  #2477242482753
# 34379                                     NaN  #2477242482753
# 34380                                     NaN  #2477242482753
# 34381  {u'currency': u'SGD', u'amount': 1000}  #2477242482753
# 34382  {u'currency': u'SGD', u'amount': 1000}  #2477242482753
# 34383  {u'currency': u'SGD', u'amount': 1000}    191569915372
# 34384  {u'currency': u'SGD', u'amount': 1000}    191569915372
# 34557  {u'currency': u'SGD', u'amount': 1000}    191569915372
# 34915                                     NaN             nan
# 34916                                     NaN             nan
# 34917                                     NaN             nan
# 34919                                     NaN  #2478646919233
# 34921                                     NaN  #2478646919233
# 34923                                     NaN  #2478646919233
# 34969                                     NaN  #2478646919233
# 34971                                     NaN    191569915442
# 34973                                     NaN    191569915442
# 35508                                     NaN    191569915442
# 35517                                     NaN    191569915490
# 35538                                     NaN    191569915490
#
#                                      id processing_method total_price  \
# 20921  4102611f7d07bef8a727f5123c391ed6               NaN       23100
# 20922  4102611f7d07bef8a727f5123c391ed6               NaN       23100
# 20923  4102611f7d07bef8a727f5123c391ed6               NaN       23100
# 20925  4102611f7d07bef8a727f5123c391ed6               NaN       23100
# 21199                      524617000000               NaN       23100
# 21202                      524617000000               NaN       23100
# 21205                      524617000000               NaN       23100
# 21596  4102611f7d07bef8a727f5123c391ed6               NaN       11100
# 21608  4102611f7d07bef8a727f5123c391ed6               NaN       11100
# 21611  4102611f7d07bef8a727f5123c391ed6               NaN       11100
# 21613  4102611f7d07bef8a727f5123c391ed6               NaN       11100
# 21626                      524617000000               NaN       11100
# 21629                      166729000000            direct       11100
# 21632                      166729000000            direct       11100
# 21635                      524617000000               NaN       11100
# 22563                      166729000000            direct       11100
# 7399                       114599000000               NaN        4200
# 7400                       114599000000               NaN        4200
# 7401                       114599000000               NaN        4200
# 22780  ddb5c4b15efb2fe2c5d4c058dd4b132a               NaN        2900
# 22781  ddb5c4b15efb2fe2c5d4c058dd4b132a               NaN        2900
# 22782                      534257000000               NaN        2900
# 22783                      534257000000               NaN        2900
# 32439  ddb5c4b15efb2fe2c5d4c058dd4b132a               NaN       10100
# 32671  88e11644dca15961ec1ed33e31559d48               NaN       10100
# 3222                       241441000000               NaN       10100
# 3256                       241441000000               NaN       10100
# 3260                       241441000000               NaN       10100
# 3262                       101293000000            direct       10100
# 3264                       101293000000            direct       10100
# ...                                 ...               ...         ...
# 35412                     2479940000000               NaN        8800
# 35413                     2479940000000               NaN        8800
# 35414  0424af03c81031e02459dc5d493d6168               NaN        8800
# 35415                     2479940000000               NaN        8800
# 35416                     2479940000000               NaN        8800
# 35417                      365993000000            direct        8800
# 35418                      365993000000            direct        8800
# 35536                      365993000000            direct        8800
# 34376  5d7da446d641db98d1da59d91fc824fa               NaN        9600
# 34377  5d7da446d641db98d1da59d91fc824fa               NaN        9600
# 34378                     2477240000000               NaN        9600
# 34379                     2477240000000               NaN        9600
# 34380                     2477240000000               NaN        9600
# 34381                     2477240000000               NaN        9600
# 34382                     2477240000000               NaN        9600
# 34383                      365086000000            direct        9600
# 34384                      365086000000            direct        9600
# 34557                      365086000000            direct        9600
# 34915  5d41d5ab028076636eff484ed5325b30               NaN       10100
# 34916  5d41d5ab028076636eff484ed5325b30               NaN       10100
# 34917  5d41d5ab028076636eff484ed5325b30               NaN       10100
# 34919                     2478650000000               NaN       10100
# 34921                     2478650000000               NaN       10100
# 34923                     2478650000000               NaN       10100
# 34969                     2478650000000               NaN       10100
# 34971                      365590000000            direct       10100
# 34973                      365590000000            direct       10100
# 35508                      365590000000            direct       10100
# 35517                      366279000000            direct       11600
# 35538                      366279000000            direct       11600
#
#            user_id  created_at                     gateway  \
# 20921  4.39846e+09  1517020064                         NaN
# 20922  4.39846e+09  1517020065                         NaN
# 20923  4.39846e+09  1517020149                         NaN
# 20925  4.39846e+09  1517020474                         NaN
# 21199  4.39846e+09  1517033172                         NaN
# 21202  4.39846e+09  1517033172                         NaN
# 21205  4.39846e+09  1517033195                         NaN
# 21596  4.39846e+09  1517066945                         NaN
# 21608  4.39846e+09  1517067225                         NaN
# 21611  4.39846e+09  1517067316                         NaN
# 21613  4.39846e+09  1517067383                         NaN
# 21626  4.39846e+09  1517067920                         NaN
# 21629  4.39846e+09  1517067970                      stripe
# 21632  4.39846e+09  1517067970                      stripe
# 21635  4.39846e+09  1517067971                      stripe
# 22563  4.39846e+09  1517236053                      stripe
# 7399   4.39846e+09  1513939724  Credit Card(Visa / Master)
# 7400   4.39846e+09  1513939724  Credit Card(Visa / Master)
# 7401   4.39846e+09  1513939724  Credit Card(Visa / Master)
# 22780  4.39846e+09  1517289557                         NaN
# 22781  4.39846e+09  1517289562                         NaN
# 22782  4.39846e+09  1517289562                         NaN
# 22783  4.39846e+09  1517289571                         NaN
# 32439  4.39846e+09  1519220139                         NaN
# 32671  4.39846e+09  1519287838                         NaN
# 3222   4.39846e+09  1513244608                         NaN
# 3256   4.39846e+09  1513244773                         NaN
# 3260   4.39846e+09  1513244947                      stripe
# 3262   4.39846e+09  1513244947                      stripe
# 3264   4.39846e+09  1513244952                      stripe
# ...            ...         ...                         ...
# 35412  87410245651  1519913625                         NaN
# 35413  87410245651  1519913633                         NaN
# 35414  87410245651  1519913683                         NaN
# 35415  87410245651  1519913767                         NaN
# 35416  87410245651  1519913817                      stripe
# 35417  87410245651  1519913822                      stripe
# 35418  87410245651  1519913822                      stripe
# 35536  87410245651  1519986483                      stripe
# 34376  89603997715  1519699518                         NaN
# 34377  89603997715  1519699520                         NaN
# 34378  89603997715  1519699555                         NaN
# 34379  89603997715  1519699556                         NaN
# 34380  89603997715  1519699583                         NaN
# 34381  89603997715  1519699592                         NaN
# 34382  89603997715  1519699675                      stripe
# 34383  89603997715  1519699678                      stripe
# 34384  89603997715  1519699678                      stripe
# 34557  89603997715  1519731745                      stripe
# 34915  98259206163  1519806620                         NaN
# 34916  98259206163  1519806626                         NaN
# 34917  98259206163  1519806698                         NaN
# 34919  98259206163  1519806699                         NaN
# 34921  98259206163  1519806699                         NaN
# 34923  98259206163  1519806868                         NaN
# 34969  98259206163  1519818641                      stripe
# 34971  98259206163  1519818645                      stripe
# 34973  98259206163  1519818645                      stripe
# 35508  98259206163  1519968908                      stripe
# 35517  99293626387  1519973222                      stripe
# 35538  99293626387  1519986547                      stripe
#
#                                   abandoned_checkout_url  \
# 20921                                                NaN
# 20922                                                NaN
# 20923                                                NaN
# 20925                                                NaN
# 21199  https://checkout.shopify.com/14402440/checkout...
# 21202  https://checkout.shopify.com/14402440/checkout...
# 21205  https://checkout.shopify.com/14402440/checkout...
# 21596                                                NaN
# 21608                                                NaN
# 21611                                                NaN
# 21613                                                NaN
# 21626  https://checkout.shopify.com/14402440/checkout...
# 21629                                                NaN
# 21632                                                NaN
# 21635  https://checkout.shopify.com/14402440/checkout...
# 22563                                                NaN
# 7399                                                 NaN
# 7400                                                 NaN
# 7401                                                 NaN
# 22780                                                NaN
# 22781                                                NaN
# 22782  https://checkout.shopify.com/14402440/checkout...
# 22783  https://checkout.shopify.com/14402440/checkout...
# 32439                                                NaN
# 32671                                                NaN
# 3222   https://checkout.shopify.com/14402440/checkout...
# 3256   https://checkout.shopify.com/14402440/checkout...
# 3260   https://checkout.shopify.com/14402440/checkout...
# 3262                                                 NaN
# 3264                                                 NaN
# ...                                                  ...
# 35412  https://checkout.shopify.com/14402440/checkout...
# 35413  https://checkout.shopify.com/14402440/checkout...
# 35414                                                NaN
# 35415  https://checkout.shopify.com/14402440/checkout...
# 35416  https://checkout.shopify.com/14402440/checkout...
# 35417                                                NaN
# 35418                                                NaN
# 35536                                                NaN
# 34376                                                NaN
# 34377                                                NaN
# 34378  https://checkout.shopify.com/14402440/checkout...
# 34379  https://checkout.shopify.com/14402440/checkout...
# 34380  https://checkout.shopify.com/14402440/checkout...
# 34381  https://checkout.shopify.com/14402440/checkout...
# 34382  https://checkout.shopify.com/14402440/checkout...
# 34383                                                NaN
# 34384                                                NaN
# 34557                                                NaN
# 34915                                                NaN
# 34916                                                NaN
# 34917                                                NaN
# 34919  https://checkout.shopify.com/14402440/checkout...
# 34921  https://checkout.shopify.com/14402440/checkout...
# 34923  https://checkout.shopify.com/14402440/checkout...
# 34969  https://checkout.shopify.com/14402440/checkout...
# 34971                                                NaN
# 34973                                                NaN
# 35508                                                NaN
# 35517                                                NaN
# 35538                                                NaN
#
#                intercom_user_id                   email
# 20921  59f839e099b81df063b4fad0   customer334@email.com
# 20922  59f839e099b81df063b4fad0   customer334@email.com
# 20923  59f839e099b81df063b4fad0   customer334@email.com
# 20925  59f839e099b81df063b4fad0   customer334@email.com
# 21199  59f839e099b81df063b4fad0   customer334@email.com
# 21202  59f839e099b81df063b4fad0   customer334@email.com
# 21205  59f839e099b81df063b4fad0   customer334@email.com
# 21596  59f839e099b81df063b4fad0   customer334@email.com
# 21608  59f839e099b81df063b4fad0   customer334@email.com
# 21611  59f839e099b81df063b4fad0   customer334@email.com
# 21613  59f839e099b81df063b4fad0   customer334@email.com
# 21626  59f839e099b81df063b4fad0   customer334@email.com
# 21629  59f839e099b81df063b4fad0   customer334@email.com
# 21632  59f839e099b81df063b4fad0   customer334@email.com
# 21635  59f839e099b81df063b4fad0   customer334@email.com
# 22563  59f839e099b81df063b4fad0   customer334@email.com
# 7399   594b25e298149d5dcffb8411  customer1074@email.com
# 7400   594b25e298149d5dcffb8411  customer1074@email.com
# 7401   594b25e298149d5dcffb8411  customer1074@email.com
# 22780  59354cf57de8d00c41a123e6  customer3442@email.com
# 22781  59354cf57de8d00c41a123e6  customer3442@email.com
# 22782  59354cf57de8d00c41a123e6  customer3442@email.com
# 22783  59354cf57de8d00c41a123e6  customer3442@email.com
# 32439  59354cf57de8d00c41a123e6  customer3442@email.com
# 32671  59354cf57de8d00c41a123e6  customer3442@email.com
# 3222   59548c001393b4a6a5ef4fb4  customer1253@email.com
# 3256   59548c001393b4a6a5ef4fb4  customer1253@email.com
# 3260   59548c001393b4a6a5ef4fb4  customer1253@email.com
# 3262   59548c001393b4a6a5ef4fb4  customer1253@email.com
# 3264   59548c001393b4a6a5ef4fb4  customer1253@email.com
# ...                         ...                     ...
# 35412  5a23734ae9c395c489daa35e   customer200@email.com
# 35413  5a23734ae9c395c489daa35e   customer200@email.com
# 35414  5a23734ae9c395c489daa35e   customer200@email.com
# 35415  5a23734ae9c395c489daa35e   customer200@email.com
# 35416  5a23734ae9c395c489daa35e   customer200@email.com
# 35417  5a23734ae9c395c489daa35e   customer200@email.com
# 35418  5a23734ae9c395c489daa35e   customer200@email.com
# 35536  5a23734ae9c395c489daa35e   customer200@email.com
# 34376  5a24e7beb7b48fa49c1596e5  customer1392@email.com
# 34377  5a24e7beb7b48fa49c1596e5  customer1392@email.com
# 34378  5a24e7beb7b48fa49c1596e5  customer1392@email.com
# 34379  5a24e7beb7b48fa49c1596e5  customer1392@email.com
# 34380  5a24e7beb7b48fa49c1596e5  customer1392@email.com
# 34381  5a24e7beb7b48fa49c1596e5  customer1392@email.com
# 34382  5a24e7beb7b48fa49c1596e5  customer1392@email.com
# 34383  5a24e7beb7b48fa49c1596e5  customer1392@email.com
# 34384  5a24e7beb7b48fa49c1596e5  customer1392@email.com
# 34557  5a24e7beb7b48fa49c1596e5  customer1392@email.com
# 34915  5a2ab17bf694cefd7087fdd5  customer1306@email.com
# 34916  5a2ab17bf694cefd7087fdd5  customer1306@email.com
# 34917  5a2ab17bf694cefd7087fdd5  customer1306@email.com
# 34919  5a2ab17bf694cefd7087fdd5  customer1306@email.com
# 34921  5a2ab17bf694cefd7087fdd5  customer1306@email.com
# 34923  5a2ab17bf694cefd7087fdd5  customer1306@email.com
# 34969  5a2ab17bf694cefd7087fdd5  customer1306@email.com
# 34971  5a2ab17bf694cefd7087fdd5  customer1306@email.com
# 34973  5a2ab17bf694cefd7087fdd5  customer1306@email.com
# 35508  5a2ab17bf694cefd7087fdd5  customer1306@email.com
# 35517  5a2aad2412ea304e971ef786  customer1121@email.com
# 35538  5a2aad2412ea304e971ef786  customer1121@email.com
#
# [16946 rows x 15 columns]

# %% [markdown]
# ## Impute Order number

# %%
def remove_order_num_with_no_hash(id):
    if not id.isdigit():
        return ""
    else:
        return id
    
previous_id = 0
def impute_order_id(id):
    global previous_id
    if id:
        previous_id = id
        return id
    else:
        return previous_id
orders["order_number"] = orders["order_number"].apply(remove_order_num_with_no_hash)
orders["order_number"] = orders["order_number"][::-1].apply(impute_order_id)
orders["order_number"] = orders["order_number"]
orders.to_csv('imputed_orders.csv')

# %% [markdown]
# ## Analytics on Customer Journey

# %%
orders["order_number"] = orders["order_number"].apply(str)
orders[orders["user_id"] == 4398460423]
# Out:
#       updated_date                    event_name creation_date  completed_at  \
# 20921   1517020064                   create-cart    1517020064           NaN
# 20922   1517020065                   update-cart    1517020064           NaN
# 20923   1517020149                   update-cart    1517020064           NaN
# 20925   1517020474                   update-cart    1517020064           NaN
# 21199   1517033172                checkout-start    1517033172           NaN
# 21202   1517033172  checkout-customer-infos-step    1517033172           NaN
# 21205   1517033195         checkout-payment-step    1517033172           NaN
# 21596   1517066945                   update-cart    1517020064           NaN
# 21608   1517067225                   update-cart    1517020064           NaN
# 21611   1517067316                   update-cart    1517020064           NaN
# 21613   1517067383                   update-cart    1517020064           NaN
# 21626   1517067920         checkout-payment-step    1517033172           NaN
# 21629   1517067970                  order-create    1517067968           NaN
# 21632   1517067970                    order-paid    1517067968           NaN
# 21635   1517067971            checkout-completed    1517033172  1.517068e+09
# 22563   1517236053               order-fulfilled    1517067968           NaN
#
#                               total_discounts   order_number  \
# 20921                                     NaN            nan
# 20922                                     NaN            nan
# 20923                                     NaN            nan
# 20925                                     NaN            nan
# 21199                                     NaN  #524617154579
# 21202                                     NaN  #524617154579
# 21205                                     NaN  #524617154579
# 21596                                     NaN            nan
# 21608                                     NaN            nan
# 21611                                     NaN            nan
# 21613                                     NaN            nan
# 21626  {u'currency': u'SGD', u'amount': 1500}  #524617154579
# 21629  {u'currency': u'SGD', u'amount': 1500}   191569914330
# 21632  {u'currency': u'SGD', u'amount': 1500}   191569914330
# 21635  {u'currency': u'SGD', u'amount': 1500}  #524617154579
# 22563  {u'currency': u'SGD', u'amount': 1500}   191569914330
#
#                                      id processing_method total_price  \
# 20921  4102611f7d07bef8a727f5123c391ed6               NaN       23100
# 20922  4102611f7d07bef8a727f5123c391ed6               NaN       23100
# 20923  4102611f7d07bef8a727f5123c391ed6               NaN       23100
# 20925  4102611f7d07bef8a727f5123c391ed6               NaN       23100
# 21199                      524617000000               NaN       23100
# 21202                      524617000000               NaN       23100
# 21205                      524617000000               NaN       23100
# 21596  4102611f7d07bef8a727f5123c391ed6               NaN       11100
# 21608  4102611f7d07bef8a727f5123c391ed6               NaN       11100
# 21611  4102611f7d07bef8a727f5123c391ed6               NaN       11100
# 21613  4102611f7d07bef8a727f5123c391ed6               NaN       11100
# 21626                      524617000000               NaN       11100
# 21629                      166729000000            direct       11100
# 21632                      166729000000            direct       11100
# 21635                      524617000000               NaN       11100
# 22563                      166729000000            direct       11100
#
#            user_id  created_at gateway  \
# 20921  4.39846e+09  1517020064     NaN
# 20922  4.39846e+09  1517020065     NaN
# 20923  4.39846e+09  1517020149     NaN
# 20925  4.39846e+09  1517020474     NaN
# 21199  4.39846e+09  1517033172     NaN
# 21202  4.39846e+09  1517033172     NaN
# 21205  4.39846e+09  1517033195     NaN
# 21596  4.39846e+09  1517066945     NaN
# 21608  4.39846e+09  1517067225     NaN
# 21611  4.39846e+09  1517067316     NaN
# 21613  4.39846e+09  1517067383     NaN
# 21626  4.39846e+09  1517067920     NaN
# 21629  4.39846e+09  1517067970  stripe
# 21632  4.39846e+09  1517067970  stripe
# 21635  4.39846e+09  1517067971  stripe
# 22563  4.39846e+09  1517236053  stripe
#
#                                   abandoned_checkout_url  \
# 20921                                                NaN
# 20922                                                NaN
# 20923                                                NaN
# 20925                                                NaN
# 21199  https://checkout.shopify.com/14402440/checkout...
# 21202  https://checkout.shopify.com/14402440/checkout...
# 21205  https://checkout.shopify.com/14402440/checkout...
# 21596                                                NaN
# 21608                                                NaN
# 21611                                                NaN
# 21613                                                NaN
# 21626  https://checkout.shopify.com/14402440/checkout...
# 21629                                                NaN
# 21632                                                NaN
# 21635  https://checkout.shopify.com/14402440/checkout...
# 22563                                                NaN
#
#                intercom_user_id                  email
# 20921  59f839e099b81df063b4fad0  customer334@email.com
# 20922  59f839e099b81df063b4fad0  customer334@email.com
# 20923  59f839e099b81df063b4fad0  customer334@email.com
# 20925  59f839e099b81df063b4fad0  customer334@email.com
# 21199  59f839e099b81df063b4fad0  customer334@email.com
# 21202  59f839e099b81df063b4fad0  customer334@email.com
# 21205  59f839e099b81df063b4fad0  customer334@email.com
# 21596  59f839e099b81df063b4fad0  customer334@email.com
# 21608  59f839e099b81df063b4fad0  customer334@email.com
# 21611  59f839e099b81df063b4fad0  customer334@email.com
# 21613  59f839e099b81df063b4fad0  customer334@email.com
# 21626  59f839e099b81df063b4fad0  customer334@email.com
# 21629  59f839e099b81df063b4fad0  customer334@email.com
# 21632  59f839e099b81df063b4fad0  customer334@email.com
# 21635  59f839e099b81df063b4fad0  customer334@email.com
# 22563  59f839e099b81df063b4fad0  customer334@email.com

# %%
group_by_events = orders['event_name'].groupby([orders['user_id'], orders['total_price']])
total = 0
cart = 0
paid = 0
for name, group in group_by_events:
    total += 1
    print name
    print group
    if 'order-paid' in list(group):
        paid += 1
        
    if 'update-cart' in list(group):
        cart += 1
# Out:
# (4398460423.0, 11100.0)
# 21596              update-cart
# 21608              update-cart
# 21611              update-cart
# 21613              update-cart
# 21626    checkout-payment-step
# 21629             order-create
# 21632               order-paid
# 21635       checkout-completed
# 22563          order-fulfilled
# Name: event_name, dtype: object
# (4398460423.0, '23100')
# 20921                     create-cart
# 20922                     update-cart
# 20923                     update-cart
# 20925                     update-cart
# 21199                  checkout-start
# 21202    checkout-customer-infos-step
# 21205           checkout-payment-step
# Name: event_name, dtype: object
# (4398461703.0, '4200')
# 7399         order-paid
# 7400       order-create
# 7401    order-fulfilled
# Name: event_name, dtype: object
# (4398462087.0, 2900.0)
# 22783    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398462087.0, '10100')
# 32439    create-cart
# 32671    update-cart
# Name: event_name, dtype: object
# (4398462087.0, '2900')
# 22780       create-cart
# 22781       update-cart
# 22782    checkout-start
# Name: event_name, dtype: object
# (4398462663.0, 16600.0)
# 29286    checkout-customer-infos-step
# 29290           checkout-payment-step
# 29294              checkout-completed
# 29298                    order-create
# 29302                      order-paid
# 29555                 order-fulfilled
# Name: event_name, dtype: object
# (4398462663.0, '10100')
# 3222    checkout-customer-infos-step
# 3256           checkout-payment-step
# 3260              checkout-completed
# 3262                      order-paid
# 3264                    order-create
# 3990                 order-fulfilled
# Name: event_name, dtype: object
# (4398462663.0, '16600')
# 24287       update-cart
# 29237       update-cart
# 29239       update-cart
# 29246       update-cart
# 29258       update-cart
# 29263       update-cart
# 29282    checkout-start
# Name: event_name, dtype: object
# (4398463047.0, 11700.0)
# 22399    checkout-customer-infos-step
# 22401           checkout-payment-step
# 22403                      order-paid
# 22405                    order-create
# 22407              checkout-completed
# 22408              checkout-completed
# 23211                 order-fulfilled
# Name: event_name, dtype: object
# (4398463047.0, '11700')
# 20880       update-cart
# 22055       update-cart
# 22056       create-cart
# 22074       update-cart
# 22075       update-cart
# 22397    checkout-start
# Name: event_name, dtype: object
# (4398463943.0, '10800')
# 8117                     update-cart
# 8118                     create-cart
# 8119                     update-cart
# 8121                     update-cart
# 8124    checkout-customer-infos-step
# 8127    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398463943.0, '12300')
# 8308                     update-cart
# 8312                     update-cart
# 8315    checkout-customer-infos-step
# 8318    checkout-customer-infos-step
# 8321           checkout-payment-step
# 8324              checkout-completed
# 8327                      order-paid
# 8330                    order-create
# 8956                 order-fulfilled
# Name: event_name, dtype: object
# (4398463943.0, '18600')
# 10392    create-cart
# Name: event_name, dtype: object
# (4398464135.0, 18600.0)
# 20109    checkout-customer-infos-step
# 20114    checkout-customer-infos-step
# 20119           checkout-payment-step
# 20206    checkout-customer-infos-step
# 20211           checkout-payment-step
# 20216           checkout-payment-step
# 20221              checkout-completed
# 20226                    order-create
# 20231                      order-paid
# 20518           checkout-payment-step
# 20564                 order-fulfilled
# Name: event_name, dtype: object
# (4398464135.0, '18600')
# 20096                     create-cart
# 20097                     update-cart
# 20099    checkout-customer-infos-step
# 20104                  checkout-start
# Name: event_name, dtype: object
# (4398464263.0, 4200.0)
# 28806    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398464263.0, 8400.0)
# 28807                     update-cart
# 28808    checkout-customer-infos-step
# 28809           checkout-payment-step
# 28810              checkout-completed
# 28811                    order-create
# 28812                      order-paid
# 29067                 order-fulfilled
# Name: event_name, dtype: object
# (4398464263.0, '4200')
# 28803       create-cart
# 28804       update-cart
# 28805    checkout-start
# Name: event_name, dtype: object
# (4398464263.0, '7600')
# 24961    checkout-customer-infos-step
# 24962                     update-cart
# 24963    checkout-customer-infos-step
# 24964           checkout-payment-step
# 24967           checkout-payment-step
# 24968              checkout-completed
# 24969                      order-paid
# 24970                    order-create
# 25914                 order-fulfilled
# Name: event_name, dtype: object
# (4398465287.0, 15800.0)
# 1421    checkout-customer-infos-step
# 1506    checkout-customer-infos-step
# 1519           checkout-payment-step
# 1523           checkout-payment-step
# 1527              checkout-completed
# 1531                      order-paid
# 1535                    order-create
# 3227                 order-fulfilled
# Name: event_name, dtype: object
# (4398465287.0, '15800')
# 1384                     create-cart
# 1385                     update-cart
# 1386                     update-cart
# 1406                     update-cart
# 1409                     update-cart
# 1413    checkout-customer-infos-step
# 1417                  checkout-start
# Name: event_name, dtype: object
# (4398467079.0, '4000')
# 28209         order-paid
# 28210    order-fulfilled
# 28211       order-create
# Name: event_name, dtype: object
# (4398467463.0, '12500')
# 1172    update-cart
# 1173    create-cart
# Name: event_name, dtype: object
# (4398469255.0, '12500')
# 19471    checkout-customer-infos-step
# 19474                 order-fulfilled
# 19477                    order-create
# 19480              checkout-completed
# 19483                      order-paid
# Name: event_name, dtype: object
# (4398469511.0, '5900')
# 19381                     create-cart
# 19382                     update-cart
# 23735                     update-cart
# 23748    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398469511.0, '7600')
# 24022    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398469703.0, 7800.0)
# 31266    checkout-customer-infos-step
# 31268                 order-fulfilled
# 31270              checkout-completed
# 31272                      order-paid
# 31274                    order-create
# Name: event_name, dtype: object
# (4398469703.0, '5000')
# 3276    checkout-customer-infos-step
# 3277    checkout-customer-infos-step
# 3278                      order-paid
# 3279              checkout-completed
# 3280                    order-create
# 3281                 order-fulfilled
# Name: event_name, dtype: object
# (4398469703.0, '7800')
# 31264    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398471367.0, 5000.0)
# 17835        update-cart
# 18253        update-cart
# 18255        update-cart
# 18316         order-paid
# 18317    order-fulfilled
# 18318       order-create
# Name: event_name, dtype: object
# (4398471367.0, '8900')
# 19317        update-cart
# 19319        update-cart
# 21290       order-create
# 21292         order-paid
# 21294    order-fulfilled
# Name: event_name, dtype: object
# (4398473351.0, '14700')
# 3761    checkout-customer-infos-step
# 3765    checkout-customer-infos-step
# 3769              checkout-completed
# 3773                    order-create
# 3777                      order-paid
# 3781                 order-fulfilled
# Name: event_name, dtype: object
# (4398473415.0, '5700')
# 1492    checkout-customer-infos-step
# 1494    checkout-customer-infos-step
# 1496    checkout-customer-infos-step
# 1498                      order-paid
# 1500                    order-create
# 1502              checkout-completed
# 1504                 order-fulfilled
# Name: event_name, dtype: object
# (4398473927.0, '9200')
# 19897    checkout-customer-infos-step
# 19899              checkout-completed
# 19901                 order-fulfilled
# 19903                    order-create
# 19905                      order-paid
# Name: event_name, dtype: object
# (4398474119.0, '4800')
# 23052                     create-cart
# 23053                     update-cart
# 23565    checkout-customer-infos-step
# 23566                    order-create
# 23567              checkout-completed
# 23568                      order-paid
# 23569                 order-fulfilled
# Name: event_name, dtype: object
# (4398474119.0, '6300')
# 31690                     create-cart
# 31691                     update-cart
# 31693                  checkout-start
# 31695    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398474119.0, '9900')
# 32225    checkout-customer-infos-step
# 32227                 order-fulfilled
# 32229                    order-create
# 32231              checkout-completed
# 32233                      order-paid
# Name: event_name, dtype: object
# (4398477191.0, '6100')
# 20933    update-cart
# Name: event_name, dtype: object
# (4398477767.0, '6100')
# 24896    checkout-customer-infos-step
# 24897                    order-create
# 24898                 order-fulfilled
# 24899                      order-paid
# 24900              checkout-completed
# Name: event_name, dtype: object
# (4398478919.0, '8400')
# 6412                     create-cart
# 6413                     update-cart
# 6414                     update-cart
# 6415                     update-cart
# 6417                     update-cart
# 6418                  checkout-start
# 6419    checkout-customer-infos-step
# 6420    checkout-customer-infos-step
# 6421    checkout-customer-infos-step
# 6422    checkout-customer-infos-step
# 6423           checkout-payment-step
# Name: event_name, dtype: object
# (4398479175.0, 12600.0)
# 1042    order-fulfilled
# Name: event_name, dtype: object
# (4398479175.0, '12600')
# 19323    checkout-customer-infos-step
# 19325                     update-cart
# 19327    checkout-customer-infos-step
# 19329           checkout-payment-step
# 19331              checkout-completed
# 19333                      order-paid
# 19335                    order-create
# 19621                 order-fulfilled
# Name: event_name, dtype: object
# (4398479175.0, '16000')
# 32591    checkout-payment-step
# 32594               order-paid
# 32597       checkout-completed
# 32600             order-create
# 32734          order-fulfilled
# Name: event_name, dtype: object
# (4398479239.0, 5000.0)
# 2075       order-create
# 2076    order-fulfilled
# 2077         order-paid
# Name: event_name, dtype: object
# (4398479687.0, '16000')
# 29761    checkout-customer-infos-step
# 29767           checkout-payment-step
# 29776              checkout-completed
# 29779                      order-paid
# 29782                    order-create
# 29877                 order-fulfilled
# Name: event_name, dtype: object
# (4398479687.0, '19800')
# 29751    checkout-customer-infos-step
# 29757    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398479687.0, '8900')
# 16486    checkout-customer-infos-step
# 16488                     update-cart
# 16490    checkout-customer-infos-step
# 16492           checkout-payment-step
# 16494                      order-paid
# 16496              checkout-completed
# 16498                    order-create
# 17097                 order-fulfilled
# Name: event_name, dtype: object
# (4398480391.0, '13550')
# 31711                     create-cart
# 31712                     update-cart
# 31721                     update-cart
# 31729                     update-cart
# 31732                  checkout-start
# 31736                     update-cart
# 31740    checkout-customer-infos-step
# 31744           checkout-payment-step
# 31748              checkout-completed
# 31752                    order-create
# 31756                      order-paid
# 32116                 order-fulfilled
# Name: event_name, dtype: object
# (4398480775.0, '6100')
# 27581    checkout-customer-infos-step
# 27582                     update-cart
# 27583    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398480775.0, '6650')
# 27584    checkout-payment-step
# Name: event_name, dtype: object
# (4398482055.0, '21200')
# 21241       order-create
# 21245         order-paid
# 21249    order-fulfilled
# Name: event_name, dtype: object
# (4398482631.0, '8700')
# 5724                     create-cart
# 5725                     update-cart
# 5726                     update-cart
# 5728    checkout-customer-infos-step
# 5730                  checkout-start
# 5732    checkout-customer-infos-step
# 5734           checkout-payment-step
# 5736              checkout-completed
# 5738                      order-paid
# 5740              checkout-completed
# 5742                    order-create
# 6231                 order-fulfilled
# Name: event_name, dtype: object
# (4398482695.0, '12400')
# 23231    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398482695.0, '16700')
# 23233    checkout-customer-infos-step
# 23236           checkout-payment-step
# 23239                      order-paid
# 23242                    order-create
# 23245              checkout-completed
# 23872                 order-fulfilled
# Name: event_name, dtype: object
# (4398482695.0, '17200')
# 21535    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398484487.0, '4300')
# 7246                     create-cart
# 7247    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398484487.0, '4850')
# 7248    checkout-payment-step
# 7249               order-paid
# 7250       checkout-completed
# 7251             order-create
# 7411          order-fulfilled
# Name: event_name, dtype: object
# (4398485063.0, '17800')
# 5973    checkout-customer-infos-step
# 5976    checkout-customer-infos-step
# 5979              checkout-completed
# 5982                    order-create
# 5985                 order-fulfilled
# 5988                      order-paid
# Name: event_name, dtype: object
# (4398485511.0, '22300')
# 20355    checkout-customer-infos-step
# 20359           checkout-payment-step
# 20363              checkout-completed
# 20367                      order-paid
# 20371                    order-create
# 20569                 order-fulfilled
# Name: event_name, dtype: object
# (4398486087.0, '15600')
# 21765                     create-cart
# 21766                     update-cart
# 21767                     update-cart
# 23108    checkout-customer-infos-step
# 23112                      order-paid
# 23116              checkout-completed
# 23120                    order-create
# 23124                 order-fulfilled
# Name: event_name, dtype: object
# (4398486087.0, '4300')
# 26179    checkout-customer-infos-step
# 26180              checkout-completed
# 26181                    order-create
# 26182                      order-paid
# 26183                 order-fulfilled
# Name: event_name, dtype: object
# (4398486279.0, '36900')
# 8630    checkout-customer-infos-step
# 8637    checkout-customer-infos-step
# 8644              checkout-completed
# 8651                 order-fulfilled
# 8658                      order-paid
# Name: event_name, dtype: object
# (4398486791.0, 5200.0)
# 17312    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398486791.0, 9300.0)
# 17804                     update-cart
# 17805                     create-cart
# 18167                     update-cart
# 18169                     update-cart
# 18172    checkout-customer-infos-step
# 18175           checkout-payment-step
# 18178              checkout-completed
# 18181                    order-create
# 18184                      order-paid
# 18402                 order-fulfilled
# Name: event_name, dtype: object
# (4398486791.0, 11600.0)
# 30726    checkout-payment-step
# 30728       checkout-completed
# 30730             order-create
# 30732               order-paid
# 31520          order-fulfilled
# Name: event_name, dtype: object
# (4398486791.0, 32600.0)
# 8469    checkout-payment-step
# 8475               order-paid
# 8481       checkout-completed
# 8487             order-create
# 8886          order-fulfilled
# Name: event_name, dtype: object
# (4398486791.0, '11600')
# 30716                     create-cart
# 30717                     update-cart
# 30718                     update-cart
# 30720                  checkout-start
# 30722    checkout-customer-infos-step
# 30724           checkout-payment-step
# Name: event_name, dtype: object
# (4398486791.0, '32600')
# 8445    checkout-customer-infos-step
# 8451           checkout-payment-step
# 8457           checkout-payment-step
# 8463           checkout-payment-step
# Name: event_name, dtype: object
# (4398486791.0, '5200')
# 17297                     update-cart
# 17298                     create-cart
# 17306                     update-cart
# 17308                  checkout-start
# 17310    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398487047.0, '4000')
# 19612    checkout-customer-infos-step
# 19613              checkout-completed
# 19614                      order-paid
# 19615                    order-create
# 19616                 order-fulfilled
# Name: event_name, dtype: object
# (4398487175.0, '12900')
# 14346                     update-cart
# 14348                     update-cart
# 14351                     update-cart
# 14353                  checkout-start
# 14355    checkout-customer-infos-step
# 14357    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398489031.0, '3600')
# 27202       order-create
# 27203    order-fulfilled
# 27204         order-paid
# Name: event_name, dtype: object
# (4398489031.0, '8400')
# 13940         order-paid
# 13942    order-fulfilled
# 13944       order-create
# Name: event_name, dtype: object
# (4398489351.0, '11300')
# 18677    checkout-customer-infos-step
# 18680           checkout-payment-step
# 18683              checkout-completed
# 18686                      order-paid
# 18689                    order-create
# 19277                 order-fulfilled
# Name: event_name, dtype: object
# (4398489543.0, '1600')
# 2771    create-cart
# 2773    update-cart
# 2775    update-cart
# Name: event_name, dtype: object
# (4398497031.0, '1600')
# 15991         order-paid
# 15992       order-create
# 15993    order-fulfilled
# Name: event_name, dtype: object
# (4398497031.0, '7800')
# 32585       order-create
# 32587    order-fulfilled
# 32589         order-paid
# Name: event_name, dtype: object
# (4398497223.0, '4100')
# 1510    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398497223.0, '4650')
# 1515    checkout-payment-step
# 1516       checkout-completed
# 1517               order-paid
# 1518             order-create
# 3212          order-fulfilled
# Name: event_name, dtype: object
# (4398498183.0, 12200.0)
# 881    checkout-customer-infos-step
# 884    checkout-customer-infos-step
# 887                 order-fulfilled
# 890                      order-paid
# 893                    order-create
# 896              checkout-completed
# Name: event_name, dtype: object
# (4398498183.0, 18699.0)
# 19995    checkout-customer-infos-step
# 19998              checkout-completed
# 20001                 order-fulfilled
# 20004                      order-paid
# 20007                    order-create
# Name: event_name, dtype: object
# (4398498183.0, '12200')
# 878    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398498183.0, '2800')
# 29413         order-paid
# 29414    order-fulfilled
# Name: event_name, dtype: object
# (4398498247.0, 10100.0)
# 17157    checkout-customer-infos-step
# 17165    checkout-customer-infos-step
# 17167                     update-cart
# 17169           checkout-payment-step
# 17171              checkout-completed
# 17173                      order-paid
# 17175                    order-create
# 17386                 order-fulfilled
# Name: event_name, dtype: object
# (4398498247.0, 17700.0)
# 17159                     update-cart
# 17162    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398498247.0, 27500.0)
# 5674    checkout-customer-infos-step
# 5678           checkout-payment-step
# 5682                    order-create
# 5686                      order-paid
# 5690              checkout-completed
# 5694              checkout-completed
# 6244                 order-fulfilled
# Name: event_name, dtype: object
# (4398498247.0, '10100')
# 17153       update-cart
# 17155    checkout-start
# Name: event_name, dtype: object
# (4398498247.0, '10700')
# 21540              update-cart
# 21542           checkout-start
# 21544    checkout-payment-step
# 21546       checkout-completed
# 21548             order-create
# 21550               order-paid
# 22577          order-fulfilled
# Name: event_name, dtype: object
# (4398498247.0, '11200')
# 10942                     update-cart
# 10945                  checkout-start
# 10948    checkout-customer-infos-step
# 10975    checkout-customer-infos-step
# 10978           checkout-payment-step
# 10996              checkout-completed
# 10999                      order-paid
# 11002                    order-create
# 11834                 order-fulfilled
# Name: event_name, dtype: object
# (4398498247.0, '27500')
# 5642                     update-cart
# 5648                     update-cart
# 5653                     update-cart
# 5657                     update-cart
# 5662                     update-cart
# 5666                  checkout-start
# 5670    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398499143.0, '4100')
# 28983                     create-cart
# 28984                     update-cart
# 28985                  checkout-start
# 28986    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398500231.0, '13900')
# 19486    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398500231.0, '17600')
# 19490    checkout-customer-infos-step
# 19495              checkout-completed
# 19500                      order-paid
# 19505                    order-create
# 19510                 order-fulfilled
# Name: event_name, dtype: object
# (4398500231.0, '8400')
# 6384    checkout-customer-infos-step
# 6387    checkout-customer-infos-step
# 6390                 order-fulfilled
# 6393                    order-create
# 6396                      order-paid
# 6399              checkout-completed
# Name: event_name, dtype: object
# (4398500615.0, '8800')
# 32184                     create-cart
# 32185                  checkout-start
# 32186    checkout-customer-infos-step
# 32187                     update-cart
# 32188           checkout-payment-step
# 32189              checkout-completed
# 32190                    order-create
# 32191                      order-paid
# 32426                 order-fulfilled
# Name: event_name, dtype: object
# (4398503879.0, '7550')
# 21682                     create-cart
# 21683                     update-cart
# 21684                     update-cart
# 21686                     update-cart
# 21688                  checkout-start
# 21690    checkout-customer-infos-step
# 21692           checkout-payment-step
# 21694              checkout-completed
# 21696                    order-create
# 21698                      order-paid
# 22540                 order-fulfilled
# Name: event_name, dtype: object
# (4398504071.0, 10300.0)
# 21779    checkout-payment-step
# 21781       checkout-completed
# 21783             order-create
# 21785               order-paid
# 23487          order-fulfilled
# Name: event_name, dtype: object
# (4398504071.0, 22100.0)
# 5776              update-cart
# 5788              update-cart
# 5795              update-cart
# 5811              update-cart
# 5819              update-cart
# 5827              update-cart
# 5836              update-cart
# 5845              update-cart
# 5854              update-cart
# 5863    checkout-payment-step
# 5872    checkout-payment-step
# 5881               order-paid
# 5890       checkout-completed
# 5899             order-create
# 6211          order-fulfilled
# Name: event_name, dtype: object
# (4398504071.0, 26700.0)
# 4880    checkout-payment-step
# 4885    checkout-payment-step
# 5700              update-cart
# 5705              update-cart
# 5709              update-cart
# 5714    checkout-payment-step
# 5719    checkout-payment-step
# Name: event_name, dtype: object
# (4398504071.0, 46100.0)
# 21348    checkout-payment-step
# 21357       checkout-completed
# 21366               order-paid
# 21375             order-create
# 23130          order-fulfilled
# Name: event_name, dtype: object
# (4398504071.0, '10300')
# 21769                     create-cart
# 21770                     update-cart
# 21771                     update-cart
# 21773                  checkout-start
# 21777    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398504071.0, '46100')
# 21306                     update-cart
# 21321                  checkout-start
# 21330    checkout-customer-infos-step
# 21339           checkout-payment-step
# Name: event_name, dtype: object
# (4398504071.0, '46900')
# 20150                     update-cart
# 20159                  checkout-start
# 20168    checkout-customer-infos-step
# 20177           checkout-payment-step
# Name: event_name, dtype: object
# (4398504199.0, '4300')
# 3730    checkout-customer-infos-step
# 3731    checkout-customer-infos-step
# 3732              checkout-completed
# 3733                      order-paid
# 3734                    order-create
# 3735                 order-fulfilled
# Name: event_name, dtype: object
# (4398505223.0, '15600')
# 28212    checkout-customer-infos-step
# 28214           checkout-payment-step
# 28216                      order-paid
# 28218                    order-create
# 28220              checkout-completed
# 29080                 order-fulfilled
# Name: event_name, dtype: object
# (4398506695.0, '7200')
# 17186                     create-cart
# 17187                     update-cart
# 17188                  checkout-start
# 17189    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398506695.0, '7750')
# 17190    checkout-payment-step
# 17191             order-create
# 17192               order-paid
# 17193       checkout-completed
# 17195              create-cart
# 17377          order-fulfilled
# Name: event_name, dtype: object
# (4398506951.0, 11100.0)
# 29965    order-paid
# Name: event_name, dtype: object
# (4398509319.0, 1300.0)
# 15557       order-create
# 15558    order-fulfilled
# 15559         order-paid
# Name: event_name, dtype: object
# (4398510471.0, 8000.0)
# 26459    checkout-payment-step
# Name: event_name, dtype: object
# (4398510471.0, 8550.0)
# 26461    checkout-payment-step
# 26463               order-paid
# 26465       checkout-completed
# 26467             order-create
# 26743          order-fulfilled
# Name: event_name, dtype: object
# (4398510471.0, '8000')
# 26068                     update-cart
# 26069                     create-cart
# 26447                     update-cart
# 26449    checkout-customer-infos-step
# 26451                  checkout-start
# 26453           checkout-payment-step
# 26457           checkout-payment-step
# Name: event_name, dtype: object
# (4398511047.0, 12100.0)
# 24920    checkout-payment-step
# 24926       checkout-completed
# 24929               order-paid
# 24932             order-create
# 25902          order-fulfilled
# Name: event_name, dtype: object
# (4398511047.0, '12100')
# 24412                     create-cart
# 24413                     update-cart
# 24414                     update-cart
# 24908                  checkout-start
# 24911    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398512455.0, '16550')
# 6177    checkout-customer-infos-step
# 6182    checkout-customer-infos-step
# 6187              checkout-completed
# 6192                    order-create
# 6197                      order-paid
# Name: event_name, dtype: object
# (4398512711.0, '32400')
# 23919    checkout-payment-step
# 23926       checkout-completed
# 23933             order-create
# 23940               order-paid
# 24761          order-fulfilled
# Name: event_name, dtype: object
# (4398515719.0, '12600')
# 24214    checkout-customer-infos-step
# 24215              checkout-completed
# 24216                    order-create
# 24217                      order-paid
# 24218                 order-fulfilled
# Name: event_name, dtype: object
# (4398516295.0, 23300.0)
# 202     checkout-customer-infos-step
# 207            checkout-payment-step
# 212               checkout-completed
# 217                       order-paid
# 222               checkout-completed
# 227                     order-create
# 1082                 order-fulfilled
# Name: event_name, dtype: object
# (4398516295.0, '23300')
# 148                     update-cart
# 187                  checkout-start
# 192    checkout-customer-infos-step
# 197    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398516295.0, '25600')
# 29618                     create-cart
# 29619                     update-cart
# 29620                     update-cart
# 29622                     update-cart
# 30012                     update-cart
# 30016                     update-cart
# 30584                     create-cart
# 30585                     update-cart
# 30587                     update-cart
# 30591                     update-cart
# 30596                     update-cart
# 30602                  checkout-start
# 30608    checkout-customer-infos-step
# 30614           checkout-payment-step
# 30620              checkout-completed
# 30626                    order-create
# 30632                      order-paid
# 31487                 order-fulfilled
# Name: event_name, dtype: object
# (4398516295.0, '9700')
# 15292                     create-cart
# 15293                     update-cart
# 15294                     update-cart
# 15296                     update-cart
# 15298                  checkout-start
# 15300    checkout-customer-infos-step
# 15302           checkout-payment-step
# 15304              checkout-completed
# 15306                      order-paid
# 15308                    order-create
# 15899                 order-fulfilled
# Name: event_name, dtype: object
# (4398516359.0, '19100')
# 13909    checkout-customer-infos-step
# 13913           checkout-payment-step
# 13917                      order-paid
# 13921              checkout-completed
# 13925                    order-create
# 14741                 order-fulfilled
# Name: event_name, dtype: object
# (4398516679.0, 4300.0)
# 15076              update-cart
# 15077    checkout-payment-step
# Name: event_name, dtype: object
# (4398516679.0, 4850.0)
# 15078    checkout-payment-step
# 15079             order-create
# 15080               order-paid
# 15081       checkout-completed
# 15176              update-cart
# 15287          order-fulfilled
# Name: event_name, dtype: object
# (4398516679.0, 8600.0)
# 15066    checkout-payment-step
# 15075    checkout-payment-step
# Name: event_name, dtype: object
# (4398516679.0, '8600')
# 14082                     update-cart
# 14083                     create-cart
# 14084    checkout-customer-infos-step
# 14085                     update-cart
# 14086                  checkout-start
# 14087           checkout-payment-step
# 15053                     create-cart
# 15054                  checkout-start
# 15055                     update-cart
# 15056    checkout-customer-infos-step
# 15058    checkout-customer-infos-step
# 15059    checkout-customer-infos-step
# 15060           checkout-payment-step
# 15073                     update-cart
# 15074           checkout-payment-step
# Name: event_name, dtype: object
# (4398516743.0, '112500')
# 7826    create-cart
# 7827    update-cart
# Name: event_name, dtype: object
# (4398516807.0, 112500.0)
# 30475    checkout-customer-infos-step
# 30484           checkout-payment-step
# 30505              checkout-completed
# 30514                    order-create
# 30523                      order-paid
# 31852                 order-fulfilled
# Name: event_name, dtype: object
# (4398516807.0, '112500')
# 30466    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398516935.0, '3400')
# 11551    checkout-customer-infos-step
# 28922    checkout-customer-infos-step
# 28923                 order-fulfilled
# 28924                    order-create
# 28925              checkout-completed
# 28926                      order-paid
# Name: event_name, dtype: object
# (4398516935.0, '4800')
# 1331    checkout-customer-infos-step
# 1332    checkout-customer-infos-step
# 1333                      order-paid
# 1334                    order-create
# 1335              checkout-completed
# 1336                 order-fulfilled
# Name: event_name, dtype: object
# (4398517255.0, '11100')
# 17563                     create-cart
# 17564                     update-cart
# 17565                     update-cart
# 17567                  checkout-start
# 17569    checkout-customer-infos-step
# 17571           checkout-payment-step
# 17573           checkout-payment-step
# 17575              checkout-completed
# 17577                    order-create
# 17579                      order-paid
# 17726                 order-fulfilled
# Name: event_name, dtype: object
# (4398518023.0, '16400')
# 15639                     create-cart
# 15640                     update-cart
# 15641                     update-cart
# 15648                     update-cart
# 15651                     update-cart
# 15655                     update-cart
# 15660                     update-cart
# 15669                     update-cart
# 15683                  checkout-start
# 15688    checkout-customer-infos-step
# 15693           checkout-payment-step
# 15698              checkout-completed
# 15703                      order-paid
# 15708                    order-create
# 16157                 order-fulfilled
# Name: event_name, dtype: object
# (4398518151.0, 27700.0)
# 14908    checkout-customer-infos-step
# 14915           checkout-payment-step
# 14922              checkout-completed
# 14929                      order-paid
# 14936                    order-create
# 15235                 order-fulfilled
# Name: event_name, dtype: object
# (4398518151.0, '27700')
# 14855                     update-cart
# 14856                     create-cart
# 14857                     update-cart
# 14859                     update-cart
# 14868                     update-cart
# 14872                     update-cart
# 14876                     update-cart
# 14881                     update-cart
# 14887                     update-cart
# 14894                  checkout-start
# 14901    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398518343.0, '15600')
# 29709    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398518343.0, '19100')
# 19405                     update-cart
# 19407                  checkout-start
# 19409    checkout-customer-infos-step
# 19411           checkout-payment-step
# 19413              checkout-completed
# 19415                      order-paid
# 19417                    order-create
# 19650                 order-fulfilled
# Name: event_name, dtype: object
# (4398518343.0, '34400')
# 21073    checkout-customer-infos-step
# 21077           checkout-payment-step
# 21093                      order-paid
# 21097                    order-create
# 21101              checkout-completed
# 23257                 order-fulfilled
# Name: event_name, dtype: object
# (4398518343.0, '8800')
# 29711    checkout-payment-step
# 29712              update-cart
# 29713    checkout-payment-step
# 29714       checkout-completed
# 29715             order-create
# 29716               order-paid
# 29880          order-fulfilled
# Name: event_name, dtype: object
# (4398518791.0, '8300')
# 14469    checkout-customer-infos-step
# 14476    checkout-customer-infos-step
# 14478                    order-create
# 14480                      order-paid
# 14482                 order-fulfilled
# 14484              checkout-completed
# Name: event_name, dtype: object
# (4398519559.0, '16600')
# 11866                     update-cart
# 11867                     create-cart
# 11868                     update-cart
# 11870                     update-cart
# 11922    checkout-customer-infos-step
# 11925                  checkout-start
# 11928    checkout-customer-infos-step
# 11931           checkout-payment-step
# 11934              checkout-completed
# 11937                      order-paid
# 11940                    order-create
# 12038                 order-fulfilled
# Name: event_name, dtype: object
# (4398521991.0, 8800.0)
# 27598    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398521991.0, 9300.0)
# 32155    checkout-customer-infos-step
# 32159           checkout-payment-step
# 32163              checkout-completed
# 32167                      order-paid
# 32169                    order-create
# 32383                 order-fulfilled
# Name: event_name, dtype: object
# (4398521991.0, '8800')
# 27585                     create-cart
# 27587                     update-cart
# 27589                  checkout-start
# 27591    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398521991.0, '9300')
# 32147       update-cart
# 32151    checkout-start
# Name: event_name, dtype: object
# (4398522247.0, '1300')
# 13344    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398522247.0, '1850')
# 13345    checkout-payment-step
# 13350       checkout-completed
# 13351               order-paid
# 13352             order-create
# 14040          order-fulfilled
# Name: event_name, dtype: object
# (4398523271.0, 5550.0)
# 8429    checkout-payment-step
# 8430               order-paid
# 8431       checkout-completed
# 8432       checkout-completed
# 8433             order-create
# 9021          order-fulfilled
# Name: event_name, dtype: object
# (4398523271.0, '5000')
# 8423                     create-cart
# 8424                     update-cart
# 8425                  checkout-start
# 8426    checkout-customer-infos-step
# 8427    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398523271.0, '5550')
# 8428    checkout-payment-step
# Name: event_name, dtype: object
# (4398525319.0, 20050.0)
# 13802    checkout-customer-infos-step
# 13809           checkout-payment-step
# 13825                      order-paid
# 13832              checkout-completed
# 13839                    order-create
# 14059                 order-fulfilled
# Name: event_name, dtype: object
# (4398525319.0, '20050')
# 13674                     create-cart
# 13675                     update-cart
# 13676                     update-cart
# 13678                     update-cart
# 13680                     update-cart
# 13682                     update-cart
# 13712                     create-cart
# 13713                     update-cart
# 13714                     update-cart
# 13716                     update-cart
# 13718                     update-cart
# 13721                     update-cart
# 13725                     update-cart
# 13730                     update-cart
# 13736                     update-cart
# 13743                     update-cart
# 13751                     update-cart
# 13760                     update-cart
# 13768                     update-cart
# 13775                     update-cart
# 13782    checkout-customer-infos-step
# 13789                  checkout-start
# Name: event_name, dtype: object
# (4398526471.0, 9900.0)
# 31974    checkout-payment-step
# 31980    checkout-payment-step
# Name: event_name, dtype: object
# (4398526471.0, 12600.0)
# 31988              update-cart
# 31990    checkout-payment-step
# 31992       checkout-completed
# 31994               order-paid
# 31996             order-create
# 32374          order-fulfilled
# Name: event_name, dtype: object
# (4398526471.0, '10400')
# 16355                     create-cart
# 16356                     update-cart
# 16357                     update-cart
# 16359                  checkout-start
# 16361    checkout-customer-infos-step
# 16363           checkout-payment-step
# 16365                    order-create
# 16367                      order-paid
# 16369              checkout-completed
# 17280                 order-fulfilled
# Name: event_name, dtype: object
# (4398526471.0, '10900')
# 16345                     update-cart
# 16347                     update-cart
# 16349                     update-cart
# 16350    checkout-customer-infos-step
# 16351           checkout-payment-step
# 16352                      order-paid
# 16353                    order-create
# 16354              checkout-completed
# 17045                 order-fulfilled
# Name: event_name, dtype: object
# (4398526471.0, '11800')
# 21720                     update-cart
# 21721                     create-cart
# 21722                     update-cart
# 31950                     create-cart
# 31951                     update-cart
# 31952                     update-cart
# 31954                     update-cart
# 31957    checkout-customer-infos-step
# 31960                  checkout-start
# 31963           checkout-payment-step
# Name: event_name, dtype: object
# (4398526471.0, '7200')
# 31966              update-cart
# 31968    checkout-payment-step
# Name: event_name, dtype: object
# (4398526471.0, '8800')
# 16371                     create-cart
# 16372                     update-cart
# 16373                  checkout-start
# 16374    checkout-customer-infos-step
# 16375           checkout-payment-step
# 16376              checkout-completed
# 16377                    order-create
# 16378                      order-paid
# 17282                 order-fulfilled
# Name: event_name, dtype: object
# (4398526471.0, '9900')
# 31970              update-cart
# 31972    checkout-payment-step
# Name: event_name, dtype: object
# (4398527175.0, 3400.0)
# 25586    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398527175.0, 3950.0)
# 25587    checkout-payment-step
# 25588       checkout-completed
# 25589               order-paid
# 25590             order-create
# 25875          order-fulfilled
# Name: event_name, dtype: object
# (4398527175.0, '3400')
# 25582                     create-cart
# 25583                     update-cart
# 25584    checkout-customer-infos-step
# 25585                  checkout-start
# Name: event_name, dtype: object
# (4398527175.0, '4050')
# 11117                     update-cart
# 11118                     create-cart
# 11119                     update-cart
# 11120                     update-cart
# 11315                     update-cart
# 11317    checkout-customer-infos-step
# 11319                  checkout-start
# 11321    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398527175.0, '4600')
# 11323    checkout-payment-step
# 11325       checkout-completed
# 11327               order-paid
# 11329             order-create
# 11848          order-fulfilled
# Name: event_name, dtype: object
# (4398528711.0, '19100')
# 27889                     update-cart
# 27892                     update-cart
# 27896                     update-cart
# 27901                     update-cart
# 28625                     create-cart
# 28626                     update-cart
# 28628                     update-cart
# 28987                     update-cart
# 28991                     update-cart
# 28997                     update-cart
# 29058                     update-cart
# 29087                  checkout-start
# 29093    checkout-customer-infos-step
# 29099           checkout-payment-step
# 29165                    order-create
# 29171              checkout-completed
# 29177                      order-paid
# 29547                 order-fulfilled
# Name: event_name, dtype: object
# (4398529223.0, 20000.0)
# 26346    checkout-customer-infos-step
# 26350           checkout-payment-step
# 26354              checkout-completed
# 26358                      order-paid
# 26362                    order-create
# 26691                 order-fulfilled
# Name: event_name, dtype: object
# (4398529223.0, 20500.0)
# 5054    checkout-payment-step
# 5162               order-paid
# 5165       checkout-completed
# 5168             order-create
# 6233          order-fulfilled
# Name: event_name, dtype: object
# (4398529223.0, '20000')
# 26338    checkout-customer-infos-step
# 26342                  checkout-start
# Name: event_name, dtype: object
# (4398529223.0, '20500')
# 5006                     create-cart
# 5007                     update-cart
# 5008                     update-cart
# 5010                     update-cart
# 5012                     update-cart
# 5015                     update-cart
# 5042                  checkout-start
# 5045    checkout-customer-infos-step
# 5048    checkout-customer-infos-step
# 5051           checkout-payment-step
# Name: event_name, dtype: object
# (4398531335.0, 4800.0)
# 32021    order-fulfilled
# 32022         order-paid
# Name: event_name, dtype: object
# (4398531335.0, '13200')
# 29505    order-fulfilled
# 29507         order-paid
# Name: event_name, dtype: object
# (4398531911.0, '11900')
# 10808    checkout-customer-infos-step
# 10811           checkout-payment-step
# 10814                      order-paid
# 10817              checkout-completed
# 10820                    order-create
# 11816                 order-fulfilled
# Name: event_name, dtype: object
# (4398531911.0, '7700')
# 24878    checkout-payment-step
# 25082    checkout-payment-step
# 25084               order-paid
# 25086             order-create
# 25088       checkout-completed
# 25885          order-fulfilled
# Name: event_name, dtype: object
# (4398532295.0, '3400')
# 20418    checkout-customer-infos-step
# 20419              checkout-completed
# 20420                 order-fulfilled
# 20421                      order-paid
# 20422                    order-create
# Name: event_name, dtype: object
# (4398532295.0, '3800')
# 552       order-create
# 553         order-paid
# 554    order-fulfilled
# Name: event_name, dtype: object
# (4398532487.0, 3400.0)
# 2973       order-create
# 2974         order-paid
# 2975    order-fulfilled
# Name: event_name, dtype: object
# (4398532487.0, '10300')
# 16810    order-fulfilled
# 16812         order-paid
# Name: event_name, dtype: object
# (4398532551.0, '11600')
# 31125              update-cart
# 31128              update-cart
# 31130    checkout-payment-step
# Name: event_name, dtype: object
# (4398532551.0, '20800')
# 31109                     update-cart
# 31113                  checkout-start
# 31117    checkout-customer-infos-step
# 31121           checkout-payment-step
# Name: event_name, dtype: object
# (4398533703.0, '34400')
# 22448    checkout-payment-step
# 22451       checkout-completed
# 22454             order-create
# 22457               order-paid
# 23834          order-fulfilled
# Name: event_name, dtype: object
# (4398536583.0, '16400')
# 11466    checkout-customer-infos-step
# 11469           checkout-payment-step
# 11472              checkout-completed
# 11475                      order-paid
# 11478                    order-create
# 11852                 order-fulfilled
# Name: event_name, dtype: object
# (4398537607.0, '14400')
# 8607    checkout-customer-infos-step
# 8610    checkout-customer-infos-step
# 8613                      order-paid
# 8616              checkout-completed
# 8619                 order-fulfilled
# Name: event_name, dtype: object
# (4398537607.0, '26200')
# 29267    checkout-customer-infos-step
# 29270                    order-create
# 29273              checkout-completed
# 29276                      order-paid
# 29279                 order-fulfilled
# Name: event_name, dtype: object
# (4398537607.0, '27200')
# 27762       order-create
# 27767    order-fulfilled
# 27772         order-paid
# Name: event_name, dtype: object
# (4398537607.0, '30700')
# 25655    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398537607.0, '32700')
# 25661    checkout-customer-infos-step
# 25668                    order-create
# 25675                      order-paid
# 25682                 order-fulfilled
# 25689              checkout-completed
# Name: event_name, dtype: object
# (4398538055.0, 13900.0)
# 22037    checkout-payment-step
# 22039               order-paid
# 22041             order-create
# 22043       checkout-completed
# 22570          order-fulfilled
# Name: event_name, dtype: object
# (4398538055.0, '13900')
# 22025                     create-cart
# 22026                     update-cart
# 22027                     update-cart
# 22029                     update-cart
# 22031    checkout-customer-infos-step
# 22033                  checkout-start
# 22035           checkout-payment-step
# Name: event_name, dtype: object
# (4398540359.0, '8600')
# 11599                     create-cart
# 11600                     update-cart
# 11601                     update-cart
# 11603    checkout-customer-infos-step
# 11605                  checkout-start
# 11607    checkout-customer-infos-step
# 11609           checkout-payment-step
# 11611                      order-paid
# 11613              checkout-completed
# 11615                    order-create
# 12051                 order-fulfilled
# Name: event_name, dtype: object
# (4398541063.0, 9050.0)
# 8724    checkout-customer-infos-step
# 8727           checkout-payment-step
# 8730                      order-paid
# 8733              checkout-completed
# 8736                    order-create
# 9276                 order-fulfilled
# Name: event_name, dtype: object
# (4398541063.0, 10700.0)
# 21872    checkout-customer-infos-step
# 21874           checkout-payment-step
# 21879              checkout-completed
# 21881                    order-create
# 21883                      order-paid
# 22496                 order-fulfilled
# Name: event_name, dtype: object
# (4398541063.0, '10700')
# 21868                     update-cart
# 21870    checkout-customer-infos-step
# Name: event_name, dtype: object
# (4398541063.0, '5900')
# 21863                     create-cart
# 21864                     update-cart
# 21865                  checkout-start
# ...
# 33453    order-fulfilled
# Name: event_name, dtype: object
# ('6808700435', 9800.0)
# 36725    checkout-customer-infos-step
# 36729           checkout-payment-step
# 36745              checkout-completed
# 36747                      order-paid
# 36749                    order-create
# 37146                 order-fulfilled
# Name: event_name, dtype: object
# ('6833635859', 17200.0)
# 33702                     create-cart
# 33703                     update-cart
# 33704                     update-cart
# 33706                     update-cart
# 33709                     update-cart
# 33712                     update-cart
# 33716    checkout-customer-infos-step
# 33720                  checkout-start
# 33724           checkout-payment-step
# 33731           checkout-payment-step
# 33735              checkout-completed
# 33739                    order-create
# 33743                      order-paid
# 34246                 order-fulfilled
# Name: event_name, dtype: object
# ('6833994771', 3800.0)
# 32887    checkout-customer-infos-step
# 32910              checkout-completed
# 32911                    order-create
# 32912                      order-paid
# 32913                 order-fulfilled
# Name: event_name, dtype: object
# ('6845327379', 6800.0)
# 34758    checkout-customer-infos-step
# Name: event_name, dtype: object
# ('6845327379', 7350.0)
# 34760    checkout-payment-step
# 34762               order-paid
# 34764       checkout-completed
# 34766             order-create
# 34996          order-fulfilled
# Name: event_name, dtype: object
# ('68521ed6a8a0868e2f3b58c', 7500.0)
# 36855    checkout-payment-step
# Name: event_name, dtype: object
# ('6852251539', 6100.0)
# 34424    checkout-customer-infos-step
# 34425                    order-create
# 34426              checkout-completed
# 34427                 order-fulfilled
# 34428                      order-paid
# Name: event_name, dtype: object
# ('6852251539', 12200.0)
# 34422    checkout-customer-infos-step
# Name: event_name, dtype: object
# ('6860522579', 17600.0)
# 36399    checkout-customer-infos-step
# 36401              checkout-completed
# 36403                    order-create
# 36405                      order-paid
# 36407                 order-fulfilled
# Name: event_name, dtype: object
# ('6861103187', 6950.0)
# 37502    checkout-payment-step
# 37504             order-create
# 37506       checkout-completed
# 37508               order-paid
# Name: event_name, dtype: object
# ('6864833491', 7700.0)
# 34618    checkout-payment-step
# 34620       checkout-completed
# 34622             order-create
# 34624               order-paid
# 35048          order-fulfilled
# Name: event_name, dtype: object
# ('6864868627', 7500.0)
# 36854    checkout-payment-step
# 36964    checkout-payment-step
# 36966              update-cart
# 36968    checkout-payment-step
# 36970    checkout-payment-step
# Name: event_name, dtype: object
# ('6864868627', 8900.0)
# 36972              update-cart
# 36975              update-cart
# 36977              update-cart
# 36988    checkout-payment-step
# 36991       checkout-completed
# 36994               order-paid
# 36997             order-create
# 37155          order-fulfilled
# Name: event_name, dtype: object
# ('6904209619', 14600.0)
# 33493                     update-cart
# 33512                  checkout-start
# 33513    checkout-customer-infos-step
# 33514           checkout-payment-step
# 33515              checkout-completed
# 33516                    order-create
# 33517                      order-paid
# 34448                 order-fulfilled
# Name: event_name, dtype: object
# ('6951347859', 17000.0)
# 33518    order-fulfilled
# 33521       order-create
# 33524         order-paid
# Name: event_name, dtype: object
# ('6952078227', 15400.0)
# 35729                     create-cart
# 35730                     update-cart
# 35731                     update-cart
# 35733                     update-cart
# 36514                     update-cart
# 36517                  checkout-start
# 36520    checkout-customer-infos-step
# 36523    checkout-customer-infos-step
# 36526           checkout-payment-step
# 36529                      order-paid
# 36532                    order-create
# 36535              checkout-completed
# 37119                 order-fulfilled
# Name: event_name, dtype: object
# ('6972369043', 8200.0)
# 37341    checkout-payment-step
# 37343       checkout-completed
# 37345               order-paid
# Name: event_name, dtype: object
# ('6996210771', 3000.0)
# 32865    checkout-customer-infos-step
# 32866              checkout-completed
# 32867                    order-create
# 32868                      order-paid
# 32869                 order-fulfilled
# Name: event_name, dtype: object
# ('7000354131', 4800.0)
# 34930    checkout-customer-infos-step
# 34931    checkout-customer-infos-step
# 34932              checkout-completed
# 34933                      order-paid
# 34934                 order-fulfilled
# Name: event_name, dtype: object
# ('7000354131', 7400.0)
# 34461    checkout-customer-infos-step
# 34462    checkout-customer-infos-step
# Name: event_name, dtype: object
# ('7000354131', 44400.0)
# 34463    checkout-customer-infos-step
# 34464              checkout-completed
# 34465                    order-create
# 34466                 order-fulfilled
# 34467                      order-paid
# Name: event_name, dtype: object
# ('7030193683', 4800.0)
# 36806    order-fulfilled
# 36807         order-paid
# Name: event_name, dtype: object
# ('7030193683', 18100.0)
# 36812         order-paid
# 36815    order-fulfilled
# Name: event_name, dtype: object
# ('7048423571', 8800.0)
# 35532    checkout-customer-infos-step
# 35533              checkout-completed
# 35534                 order-fulfilled
# 35535                      order-paid
# Name: event_name, dtype: object
# ('7068429587', 7800.0)
# 36087    checkout-payment-step
# 36089       checkout-completed
# 36091             order-create
# 36093               order-paid
# 36462          order-fulfilled
# Name: event_name, dtype: object
# ('7085922067', 4300.0)
# 36743    update-cart
# 36744    create-cart
# Name: event_name, dtype: object
# ('7086328915', 4300.0)
# 33359    checkout-customer-infos-step
# 33360                  checkout-start
# 33361                     update-cart
# 35520    checkout-customer-infos-step
# 35521              checkout-completed
# 35522                    order-create
# 35523                 order-fulfilled
# 35524                      order-paid
# Name: event_name, dtype: object
# ('7110042195', 11100.0)
# 36594                     create-cart
# 36595                     update-cart
# 36602                     update-cart
# 36604                     update-cart
# 36606    checkout-customer-infos-step
# 36608                     update-cart
# 36610                  checkout-start
# 36612           checkout-payment-step
# 36614              checkout-completed
# 36616                    order-create
# 36618                      order-paid
# 37129                 order-fulfilled
# Name: event_name, dtype: object
# ('7125378515', 8200.0)
# 35586    checkout-customer-infos-step
# 35588              checkout-completed
# 35590                      order-paid
# 35592                    order-create
# 35594                 order-fulfilled
# Name: event_name, dtype: object
# ('7128909523', 6800.0)
# 33195       order-create
# 33196         order-paid
# 33197    order-fulfilled
# Name: event_name, dtype: object
# ('7133217299', 8300.0)
# 32797                     update-cart
# 32801    checkout-customer-infos-step
# Name: event_name, dtype: object
# ('7133217299', 11600.0)
# 35310    checkout-customer-infos-step
# 35314           checkout-payment-step
# 35318              checkout-completed
# 35322                    order-create
# 35324                      order-paid
# 35540                 order-fulfilled
# Name: event_name, dtype: object
# ('7148260371', 17000.0)
# 34005                     create-cart
# 34006                     update-cart
# 34017                     update-cart
# 34019                     update-cart
# 34022                     update-cart
# 34026                     update-cart
# 34035                     update-cart
# 34047                     update-cart
# 34052                     update-cart
# 34056                  checkout-start
# 34060    checkout-customer-infos-step
# 34064    checkout-customer-infos-step
# 34068           checkout-payment-step
# 34073              checkout-completed
# 34077                    order-create
# 34081                      order-paid
# 34533                 order-fulfilled
# Name: event_name, dtype: object
# ('7217103827', 23000.0)
# 32934                     create-cart
# 32935                     update-cart
# 32936                     update-cart
# 32938                     update-cart
# 32941    checkout-customer-infos-step
# 32944                  checkout-start
# 32947           checkout-payment-step
# 32950              checkout-completed
# 32953                      order-paid
# 32956                    order-create
# 34236                 order-fulfilled
# Name: event_name, dtype: object
# ('7217402771', 15600.0)
# 34031    checkout-customer-infos-step
# 34033           checkout-payment-step
# 34041              checkout-completed
# 34043                    order-create
# 34045                      order-paid
# 34547                 order-fulfilled
# Name: event_name, dtype: object
# ('7234394195', 5400.0)
# 34166    checkout-customer-infos-step
# 34170    checkout-customer-infos-step
# 34172              checkout-completed
# 34174                 order-fulfilled
# 34176                      order-paid
# 34178                    order-create
# Name: event_name, dtype: object
# ('7236587411', 1300.0)
# 36291    checkout-customer-infos-step
# 36292              checkout-completed
# 36293                 order-fulfilled
# 36294                      order-paid
# Name: event_name, dtype: object
# ('7236774995', 7400.0)
# 36804                     update-cart
# 36805                     create-cart
# 36808                     update-cart
# 36826                  checkout-start
# 36828    checkout-customer-infos-step
# 36830    checkout-customer-infos-step
# 36832    checkout-customer-infos-step
# 36834    checkout-customer-infos-step
# 36836           checkout-payment-step
# 36838                    order-create
# 36840              checkout-completed
# 36842                      order-paid
# 37158                 order-fulfilled
# Name: event_name, dtype: object
# ('7254975507', 4800.0)
# 37634    checkout-customer-infos-step
# 37635                    order-create
# 37636              checkout-completed
# 37637                      order-paid
# 37638                 order-fulfilled
# Name: event_name, dtype: object
# ('7287323667', 13700.0)
# 33275    checkout-customer-infos-step
# 33277           checkout-payment-step
# 33279              checkout-completed
# 33281                      order-paid
# 33283                    order-create
# 34217                 order-fulfilled
# Name: event_name, dtype: object
# ('7290911379', 3600.0)
# 35330    checkout-customer-infos-step
# 35331                      order-paid
# 35332                 order-fulfilled
# 35333                    order-create
# 35334              checkout-completed
# Name: event_name, dtype: object
# ('7296727123', 5500.0)
# 34113    checkout-customer-infos-step
# Name: event_name, dtype: object
# ('7296727123', 11000.0)
# 34114    checkout-customer-infos-step
# 34115           checkout-payment-step
# 34122              checkout-completed
# 34123                    order-create
# 34124                      order-paid
# 34549                 order-fulfilled
# Name: event_name, dtype: object
# ('7310955155', 8100.0)
# 33327                     update-cart
# 33329    checkout-customer-infos-step
# 33335           checkout-payment-step
# 33341              checkout-completed
# 33343                      order-paid
# 33345                    order-create
# 34227                 order-fulfilled
# Name: event_name, dtype: object
# ('7324752211', 15200.0)
# 33460                     update-cart
# 33462                     update-cart
# 33527                     update-cart
# 33531                     update-cart
# 33534                     update-cart
# 33537           checkout-payment-step
# 34116    checkout-customer-infos-step
# 34119           checkout-payment-step
# 34125              checkout-completed
# 34128                      order-paid
# 34131                    order-create
# 34552                 order-fulfilled
# Name: event_name, dtype: object
# ('7329032659', 17600.0)
# 35561    checkout-customer-infos-step
# 35563           checkout-payment-step
# 35565                      order-paid
# 35567              checkout-completed
# 35569                    order-create
# 36456                 order-fulfilled
# Name: event_name, dtype: object
# ('7346179859', 25350.0)
# 32892    order-fulfilled
# Name: event_name, dtype: object
# ('7353766483', 18400.0)
# 34160    order-fulfilled
# 34163         order-paid
# Name: event_name, dtype: object
# ('7354501843', 5900.0)
# 35481                     create-cart
# 35482                     update-cart
# 35483                  checkout-start
# 35484    checkout-customer-infos-step
# 35485           checkout-payment-step
# 35499              checkout-completed
# 35500                    order-create
# 35501                      order-paid
# 35548                 order-fulfilled
# Name: event_name, dtype: object
# ('7371852179', 5000.0)
# 36949    checkout-customer-infos-step
# 36952              checkout-completed
# 36953                 order-fulfilled
# 36954                    order-create
# 36955                      order-paid
# Name: event_name, dtype: object
# ('7373668947', 4300.0)
# 34323                     create-cart
# 34324                  checkout-start
# 34325    checkout-customer-infos-step
# Name: event_name, dtype: object
# ('7373668947', 4850.0)
# 34326              update-cart
# 34327    checkout-payment-step
# 34328       checkout-completed
# 34329             order-create
# 34330               order-paid
# 34543          order-fulfilled
# Name: event_name, dtype: object
# ('77115031571', 24900.0)
# 35384    checkout-customer-infos-step
# 35392           checkout-payment-step
# 35397              checkout-completed
# 35402                      order-paid
# 35407                    order-create
# 35494                 order-fulfilled
# 35512                 order-fulfilled
# Name: event_name, dtype: object
# ('81479663635', 9100.0)
# 34468    checkout-customer-infos-step
# 34470              checkout-completed
# 34472                    order-create
# 34474                      order-paid
# 34476                 order-fulfilled
# Name: event_name, dtype: object
# ('8532754451', 6400.0)
# 34280                     create-cart
# 34281                     update-cart
# 34282    checkout-customer-infos-step
# 34284                  checkout-start
# Name: event_name, dtype: object
# ('8532754451', 9100.0)
# 34286                     update-cart
# 34288                     update-cart
# 34291    checkout-customer-infos-step
# 34294           checkout-payment-step
# 34297              checkout-completed
# 34300                    order-create
# 34303                      order-paid
# 34530                 order-fulfilled
# Name: event_name, dtype: object
# ('87410245651', 8800.0)
# 35412    checkout-customer-infos-step
# 35413           checkout-payment-step
# 35414                     update-cart
# 35415           checkout-payment-step
# 35416              checkout-completed
# 35417                      order-paid
# 35418                    order-create
# 35536                 order-fulfilled
# Name: event_name, dtype: object
# ('89603997715', 9600.0)
# 34376                     create-cart
# 34377                     update-cart
# 34378                  checkout-start
# 34379    checkout-customer-infos-step
# 34380           checkout-payment-step
# 34381           checkout-payment-step
# 34382              checkout-completed
# 34383                      order-paid
# 34384                    order-create
# 34557                 order-fulfilled
# Name: event_name, dtype: object
# ('98259206163', 10100.0)
# 34915                     create-cart
# 34916                     update-cart
# 34917                     update-cart
# 34919    checkout-customer-infos-step
# 34921                  checkout-start
# 34923           checkout-payment-step
# 34969              checkout-completed
# 34971                    order-create
# 34973                      order-paid
# 35508                 order-fulfilled
# Name: event_name, dtype: object
# ('99293626387', 11600.0)
# 35517       order-create
# 35538    order-fulfilled
# Name: event_name, dtype: object

# %% [markdown]
# ## Basic Analysis

# %%
import matplotlib.pyplot as plt
no_cart = total - cart
no_paid = total - paid
plt.pie([cart, no_cart], labels=['Cart', 'No Cart'], colors=['r', 'b'], startangle=90, autopct='%.1f%%')
plt.show()
plt.pie([paid, no_paid], labels=['Paid', 'No Paid'], colors=['r', 'b'], startangle=90, autopct='%.1f%%')
plt.show()
